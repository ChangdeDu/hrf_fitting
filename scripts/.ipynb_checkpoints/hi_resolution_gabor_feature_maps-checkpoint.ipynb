# %% [markdown]
# ## Make hi-res convolutions go faster

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import h5py
from glob import glob
from scipy.io import loadmat
from hrf_fitting.src.gabor_feature_dictionaries import gabor_feature_maps
from hrf_fitting.src.features import make_gabor
from skimage.transform import resize
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### load crcns stimuli

# %%
stim_location = '/media/tnaselar/Data/crcns_datasets/vim-1/Stimuli.mat'
crcns_stim_dict = loadmat(stim_location)

# %%
##need 'stimVal' and 'stimTrn'
print crcns_stim_dict['stimVal'].shape
print crcns_stim_dict['stimTrn'].shape
# Out:
# (120, 128, 128)
# (1750, 128, 128)

# %%
##remember stim params
Ttrn = crcns_stim_dict['stimTrn'].shape[0]
Tval = crcns_stim_dict['stimVal'].shape[0]
T = Ttrn+Tval
native_stim_size = crcns_stim_dict['stimTrn'].shape[1]
n_image_channels = 1 ##could be 3 for color images.
stim_size = 512

# %%
plt.imshow(crcns_stim_dict['stimVal'][0,:,:],cmap='gray')

# %% [markdown]
# #### parameters of the gabor stack

# %%
n_orientations = 12
deg_per_stimulus = 20
lowest_sp_freq = .2 ##cyc/deg
highest_sp_freq = 4.165
num_sp_freq = 12
pix_per_cycle = 4
complex_cell = True

# %% [markdown]
# #### create gabor_feature_map object

# %%
gfm = gabor_feature_maps(n_orientations,
                         deg_per_stimulus,
                         (lowest_sp_freq,highest_sp_freq,num_sp_freq),
                         pix_per_cycle=pix_per_cycle,complex_cell=complex_cell)

# %% [markdown]
# #### see the table of gabor params

# %%
gfm.gbr_table.tail(15)
# Out:
#      cycles per deg.  cycles_per_filter  filter size (deg.)  pix per stimulus  \
# 129         2.398128                  4            1.667968        191.850203
# 130         3.160412                  4            1.265658        252.832925
# 131         4.165000                  4            0.960384        333.200000
# 132         0.200000                  4           20.000000         16.000000
# 133         0.263573                  4           15.176046         21.085861
# 134         0.347354                  4           11.515618         27.788347
# 135         0.457767                  4            8.738078         36.621327
# 136         0.603275                  4            6.630473         48.262014
# 137         0.795036                  4            5.031218         63.602884
# 138         1.047751                  4            3.817700         83.820099
# 139         1.380796                  4            2.896880        110.463687
# 140         1.819705                  4            2.198159        145.576374
# 141         2.398128                  4            1.667968        191.850203
# 142         3.160412                  4            1.265658        252.832925
# 143         4.165000                  4            0.960384        333.200000
#
#      pix_per_filter  radius of Gauss. envelope (deg)  orientation
# 129              16                         0.416992     2.617994
# 130              16                         0.316414     2.617994
# 131              16                         0.240096     2.617994
# 132              16                         5.000000     2.879793
# 133              16                         3.794011     2.879793
# 134              16                         2.878905     2.879793
# 135              16                         2.184519     2.879793
# 136              16                         1.657618     2.879793
# 137              16                         1.257805     2.879793
# 138              16                         0.954425     2.879793
# 139              16                         0.724220     2.879793
# 140              16                         0.549540     2.879793
# 141              16                         0.416992     2.879793
# 142              16                         0.316414     2.879793
# 143              16                         0.240096     2.879793

# %% [markdown]
# #### see one of the gabors
# note that all gabors have the same size and same number of cycles. the only variation is in the orientation. this
# is because when we apply the filters we downsample the images to low frequncy filtering (instead of upsampling the gabors).

# %%
o = 1
plt.imshow(np.real(gfm.filter_stack[o,0,:,:]),cmap='gray')

# %% [markdown]
# #### test on a grating

# %%
##test. make a horizontal gabor, then filter it with bank of gabors to get sp. freq tuning
test_deg_per_stim = 20.
test_cycles_per_stim = 40. 
print 'cyc/deg: %f' %(test_cycles_per_stim/test_deg_per_stim)
test_stim_size = 128
test_grating = make_gabor(test_cycles_per_stim,np.pi/2.,np.pi/2.,(0,0),2*test_stim_size,test_stim_size)

plt.imshow(test_grating,cmap='gray')
# Out:
# cyc/deg: 2.000000

# %%
test_feat_dict = gfm.create_feature_maps(test_grating[np.newaxis,np.newaxis,:,:],interp_order=3)
# Out:
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.002010 s.
# feature 1 took 0.001601 s.
# feature 2 took 0.001790 s.
# feature 3 took 0.001672 s.
# feature 4 took 0.001754 s.
# feature 5 took 0.002066 s.
# feature 6 took 0.002339 s.
# feature 7 took 0.002969 s.
# feature 8 took 0.003959 s.
# feature 9 took 0.005985 s.
# feature 10 took 0.008993 s.
# feature 11 took 0.014393 s.
# feature 12 took 0.001683 s.
# feature 13 took 0.001578 s.
# feature 14 took 0.001591 s.
# feature 15 took 0.001668 s.
# feature 16 took 0.001736 s.
# feature 17 took 0.002202 s.
# feature 18 took 0.003120 s.
# feature 19 took 0.003158 s.
# feature 20 took 0.003946 s.
# feature 21 took 0.005637 s.
# feature 22 took 0.009241 s.
# feature 23 took 0.015439 s.
# feature 24 took 0.001823 s.
# feature 25 took 0.001513 s.
# feature 26 took 0.001482 s.
# feature 27 took 0.001662 s.
# feature 28 took 0.001796 s.
# feature 29 took 0.002274 s.
# feature 30 took 0.002450 s.
# feature 31 took 0.003705 s.
# feature 32 took 0.004955 s.
# feature 33 took 0.007025 s.
# feature 34 took 0.011398 s.
# feature 35 took 0.017483 s.
# feature 36 took 0.002176 s.
# feature 37 took 0.002096 s.
# feature 38 took 0.002208 s.
# feature 39 took 0.002152 s.
# feature 40 took 0.002213 s.
# feature 41 took 0.002626 s.
# feature 42 took 0.002932 s.
# feature 43 took 0.003713 s.
# feature 44 took 0.004917 s.
# feature 45 took 0.007470 s.
# feature 46 took 0.011717 s.
# feature 47 took 0.018031 s.
# feature 48 took 0.002023 s.
# feature 49 took 0.002067 s.
# feature 50 took 0.002013 s.
# feature 51 took 0.002109 s.
# feature 52 took 0.002174 s.
# feature 53 took 0.002640 s.
# feature 54 took 0.002933 s.
# feature 55 took 0.003729 s.
# feature 56 took 0.005030 s.
# feature 57 took 0.007136 s.
# feature 58 took 0.011572 s.
# feature 59 took 0.017379 s.
# feature 60 took 0.002195 s.
# feature 61 took 0.002085 s.
# feature 62 took 0.001926 s.
# feature 63 took 0.002268 s.
# feature 64 took 0.002304 s.
# feature 65 took 0.002740 s.
# feature 66 took 0.002915 s.
# feature 67 took 0.003933 s.
# feature 68 took 0.005371 s.
# feature 69 took 0.007164 s.
# feature 70 took 0.011031 s.
# feature 71 took 0.017656 s.
# feature 72 took 0.002158 s.
# feature 73 took 0.002000 s.
# feature 74 took 0.002057 s.
# feature 75 took 0.002109 s.
# feature 76 took 0.002225 s.
# feature 77 took 0.002620 s.
# feature 78 took 0.003009 s.
# feature 79 took 0.004591 s.
# feature 80 took 0.005114 s.
# feature 81 took 0.007538 s.
# feature 82 took 0.011148 s.
# feature 83 took 0.017894 s.
# feature 84 took 0.002106 s.
# feature 85 took 0.002010 s.
# feature 86 took 0.002019 s.
# feature 87 took 0.002199 s.
# feature 88 took 0.002199 s.
# feature 89 took 0.002623 s.
# feature 90 took 0.002935 s.
# feature 91 took 0.004076 s.
# feature 92 took 0.005119 s.
# feature 93 took 0.007391 s.
# feature 94 took 0.011565 s.
# feature 95 took 0.017464 s.
# feature 96 took 0.002003 s.
# feature 97 took 0.001994 s.
# feature 98 took 0.002108 s.
# feature 99 took 0.002120 s.
# feature 100 took 0.002190 s.
# feature 101 took 0.002644 s.
# feature 102 took 0.003081 s.
# feature 103 took 0.004050 s.
# feature 104 took 0.005119 s.
# feature 105 took 0.007138 s.
# feature 106 took 0.011428 s.
# feature 107 took 0.017630 s.
# feature 108 took 0.001977 s.
# feature 109 took 0.001975 s.
# feature 110 took 0.002118 s.
# feature 111 took 0.002074 s.
# feature 112 took 0.002246 s.
# feature 113 took 0.002679 s.
# feature 114 took 0.003379 s.
# feature 115 took 0.003750 s.
# feature 116 took 0.005717 s.
# feature 117 took 0.007155 s.
# feature 118 took 0.010974 s.
# feature 119 took 0.017653 s.
# feature 120 took 0.002028 s.
# feature 121 took 0.002157 s.
# feature 122 took 0.002100 s.
# feature 123 took 0.002147 s.
# feature 124 took 0.002180 s.
# feature 125 took 0.002607 s.
# feature 126 took 0.002953 s.
# feature 127 took 0.003720 s.
# feature 128 took 0.004918 s.
# feature 129 took 0.007335 s.
# feature 130 took 0.011048 s.
# feature 131 took 0.017334 s.
# feature 132 took 0.002093 s.
# feature 133 took 0.002103 s.
# feature 134 took 0.002103 s.
# feature 135 took 0.002127 s.
# feature 136 took 0.002219 s.
# feature 137 took 0.002588 s.
# feature 138 took 0.002902 s.
# feature 139 took 0.003716 s.
# feature 140 took 0.005254 s.
# feature 141 took 0.007808 s.
# feature 142 took 0.011774 s.
# feature 143 took 0.018414 s.

# %% [markdown]
# ##### frequency sensitivity

# %%
freqs,mean_resp=gfm.sensitivity(test_feat_dict, 'cycles per deg.')
plt.plot(freqs,mean_resp)

# %% [markdown]
# Everything depends critically on the pixels per cycle. Without it, you get weird aliasing where the spatial
# frequency tuning has many spurious bumps for higher frequencies. For natural scenes, we seem to get nice 1/f scaling when pix/cyc = 6.

# %% [markdown]
# ##### orientation sensitivity

# %%
oris,mean_resp=gfm.sensitivity(test_feat_dict, 'orientation')
plt.plot(oris,mean_resp)

# %% [markdown]
# #### test on real stimuli

# %%
real_feat_dict = gfm.create_feature_maps(crcns_stim_dict['stimTrn'][0:10,np.newaxis,:,:])
# Out:
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.014101 s.
# feature 1 took 0.013758 s.
# feature 2 took 0.014231 s.
# feature 3 took 0.014722 s.
# feature 4 took 0.015828 s.
# feature 5 took 0.018374 s.
# feature 6 took 0.022976 s.
# feature 7 took 0.031404 s.
# feature 8 took 0.042695 s.
# feature 9 took 0.064007 s.
# feature 10 took 0.100815 s.
# feature 11 took 0.166038 s.
# feature 12 took 0.014867 s.
# feature 13 took 0.027730 s.
# feature 14 took 0.020929 s.
# feature 15 took 0.053229 s.
# feature 16 took 0.039393 s.
# feature 17 took 0.019302 s.
# feature 18 took 0.031910 s.
# feature 19 took 0.031091 s.
# feature 20 took 0.044169 s.
# feature 21 took 0.064685 s.
# feature 22 took 0.103187 s.
# feature 23 took 0.166807 s.
# feature 24 took 0.014834 s.
# feature 25 took 0.014166 s.
# feature 26 took 0.014619 s.
# feature 27 took 0.015276 s.
# feature 28 took 0.017299 s.
# feature 29 took 0.020517 s.
# feature 30 took 0.022563 s.
# feature 31 took 0.031512 s.
# feature 32 took 0.043429 s.
# feature 33 took 0.064707 s.
# feature 34 took 0.105936 s.
# feature 35 took 0.173977 s.
# feature 36 took 0.038325 s.
# feature 37 took 0.013942 s.
# feature 38 took 0.014658 s.
# feature 39 took 0.015087 s.
# feature 40 took 0.015714 s.
# feature 41 took 0.018067 s.
# feature 42 took 0.022864 s.
# feature 43 took 0.031226 s.
# feature 44 took 0.043804 s.
# feature 45 took 0.064388 s.
# feature 46 took 0.102294 s.
# feature 47 took 0.167113 s.
# feature 48 took 0.014854 s.
# feature 49 took 0.014111 s.
# feature 50 took 0.014256 s.
# feature 51 took 0.014539 s.
# feature 52 took 0.016615 s.
# feature 53 took 0.018103 s.
# feature 54 took 0.022087 s.
# feature 55 took 0.031653 s.
# feature 56 took 0.043331 s.
# feature 57 took 0.064538 s.
# feature 58 took 0.104256 s.
# feature 59 took 0.172055 s.
# feature 60 took 0.014853 s.
# feature 61 took 0.014182 s.
# feature 62 took 0.014535 s.
# feature 63 took 0.014849 s.
# feature 64 took 0.015812 s.
# feature 65 took 0.018329 s.
# feature 66 took 0.022342 s.
# feature 67 took 0.031627 s.
# feature 68 took 0.045619 s.
# feature 69 took 0.065254 s.
# feature 70 took 0.105764 s.
# feature 71 took 0.167319 s.
# feature 72 took 0.015266 s.
# feature 73 took 0.014317 s.
# feature 74 took 0.016390 s.
# feature 75 took 0.016663 s.
# feature 76 took 0.016022 s.
# feature 77 took 0.020777 s.
# feature 78 took 0.022847 s.
# feature 79 took 0.032259 s.
# feature 80 took 0.044305 s.
# feature 81 took 0.072934 s.
# feature 82 took 0.140199 s.
# feature 83 took 0.167239 s.
# feature 84 took 0.014960 s.
# feature 85 took 0.014150 s.
# feature 86 took 0.014506 s.
# feature 87 took 0.015513 s.
# feature 88 took 0.016997 s.
# feature 89 took 0.018356 s.
# feature 90 took 0.023325 s.
# feature 91 took 0.031246 s.
# feature 92 took 0.045055 s.
# feature 93 took 0.065892 s.
# feature 94 took 0.106755 s.
# feature 95 took 0.168378 s.
# feature 96 took 0.014926 s.
# feature 97 took 0.013914 s.
# feature 98 took 0.014239 s.
# feature 99 took 0.014573 s.
# feature 100 took 0.016319 s.
# feature 101 took 0.018380 s.
# feature 102 took 0.023035 s.
# feature 103 took 0.031605 s.
# feature 104 took 0.106989 s.
# feature 105 took 0.065372 s.
# feature 106 took 0.103470 s.
# feature 107 took 0.166384 s.
# feature 108 took 0.014996 s.
# feature 109 took 0.013920 s.
# feature 110 took 0.014147 s.
# feature 111 took 0.014562 s.
# feature 112 took 0.015724 s.
# feature 113 took 0.018584 s.
# feature 114 took 0.022332 s.
# feature 115 took 0.030887 s.
# feature 116 took 0.043313 s.
# feature 117 took 0.064925 s.
# feature 118 took 0.102354 s.
# feature 119 took 0.168226 s.
# feature 120 took 0.029970 s.
# feature 121 took 0.030789 s.
# feature 122 took 0.036901 s.
# feature 123 took 0.044594 s.
# feature 124 took 0.040813 s.
# feature 125 took 0.015193 s.
# feature 126 took 0.024313 s.
# feature 127 took 0.025868 s.
# feature 128 took 0.044721 s.
# feature 129 took 0.051396 s.
# feature 130 took 0.090908 s.
# feature 131 took 0.139005 s.
# feature 132 took 0.016728 s.
# feature 133 took 0.013504 s.
# feature 134 took 0.011253 s.
# feature 135 took 0.013223 s.
# feature 136 took 0.017566 s.
# feature 137 took 0.018677 s.
# feature 138 took 0.019222 s.
# feature 139 took 0.025541 s.
# feature 140 took 0.035885 s.
# feature 141 took 0.055047 s.
# feature 142 took 0.091309 s.
# feature 143 took 0.200221 s.

# %%
sdx = 9
plt.figure(figsize=(30,60))
num_plots = gfm.num_sp_freq[0]
imshape = (60,60)
plt.subplot(1,num_plots,1)
plt.imshow(resize(crcns_stim_dict['stimTrn'][sdx,:,:],imshape,order=3),cmap='gray')
for pi in np.arange(2,num_plots+1):
    plt.subplot(1,num_plots,pi)
    plt.imshow(resize(real_feat_dict[gfm.gbr_table.index[pi-2]][sdx,0,:,:],imshape,order=3,preserve_range=True))

# %%
freqs,mean_resp=gfm.sensitivity(real_feat_dict, 'cycles per deg.')
plt.plot(freqs,mean_resp,'r')
plt.plot(freqs, 1./(freqs**1.3),hold=True)

# %% [markdown]
# some kind of 1/f spectrum, just as you'd expect.
