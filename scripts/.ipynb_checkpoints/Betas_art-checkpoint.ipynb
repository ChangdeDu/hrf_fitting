# %% [markdown]
# ##Fit betas for art, freq, and match-non-match data
# July.2015 high-resolution CMRR data for the "match_nonmatch" project.
#
# Project notes: https://drive.google.com/open?id=1m1rmotkmtgwY99Q_k71YDorUPq_DkCSJ0LselY13_v4

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import hrf_fitting.src.preprocessing as preproc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage
import nibabel as nib
import pickle
import matplotlib.animation as animation
import hrf_estimation as he
import operator

from PIL import Image
from hrf_fitting.src.features import construct_placement_grid,make_kernel_grid,complex_ripple_filter,compute_grid_corners
from scipy.signal import convolve2d
from os import path
from sklearn import linear_model
from glob import glob
from sklearn.metrics import explained_variance_score,r2_score
from scipy.stats.mstats import zscore
from joblib import Parallel, delayed
from time import time
from scipy.interpolate import griddata
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['griddata']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ###Select data

# %% [markdown]
# select a subject and corresponding database

# %%
subject = 's1055'
db =  '/media/tnaselar/Data/July_2015_preproc/'+subject+'/PS/aligned_db.csv'

# %% [markdown]
# import into pandas dataframe and view it

# %%
data_db = pd.io.parsers.read_csv(db,header=0)
data_db
# Out:
#     runID        date subject      experiment  \
# 0       0  27/07/2015   s1055  match_nonmatch
# 1       1  27/07/2015   s1055  match_nonmatch
# 2       2  27/07/2015   s1055  match_nonmatch
# 3       3  27/07/2015   s1055  match_nonmatch
# 4       4  27/07/2015   s1055  match_nonmatch
# 5       5  27/07/2015   s1055  match_nonmatch
# 6       6  27/07/2015   s1055  match_nonmatch
# 7       7  27/07/2015   s1055  match_nonmatch
# 8       8  27/07/2015   s1055  match_nonmatch
# 9       9  27/07/2015   s1055  match_nonmatch
# 10     10  27/07/2015   s1055  match_nonmatch
# 11     11  27/07/2015   s1055  match_nonmatch
# 12     12  27/07/2015   s1055  match_nonmatch
# 13     13  27/07/2015   s1055  match_nonmatch
# 14     14  27/07/2015   s1055  match_nonmatch
# 15     15  29/07/2015   s1055  match_nonmatch
# 16     16  29/07/2015   s1055  match_nonmatch
# 17     17  29/07/2015   s1055  match_nonmatch
# 18     18  29/07/2015   s1055  match_nonmatch
# 19     19  04/08/2015   s1055  match_nonmatch
# 20     20  04/08/2015   s1055  match_nonmatch
# 21     21  04/08/2015   s1055  match_nonmatch
# 22     22  04/08/2015   s1055  match_nonmatch
# 23     23  04/08/2015   s1055  match_nonmatch
# 24     24  04/08/2015   s1055  match_nonmatch
# 25     25  04/08/2015   s1055  match_nonmatch
# 26     26  04/08/2015   s1055  match_nonmatch
# 27     27  04/08/2015   s1055  match_nonmatch
# 28     28  04/08/2015   s1055  match_nonmatch
# 29     29  04/08/2015   s1055  match_nonmatch
# 30     30  04/08/2015   s1055  match_nonmatch
# 31     31  27/07/2015   s1055  match_nonmatch
# 32     32  29/07/2015   s1055  match_nonmatch
# 33     33  29/07/2015   s1055  match_nonmatch
# 34     34  04/08/2015   s1055  match_nonmatch
# 35     35  04/08/2015   s1055  match_nonmatch
# 36     36  04/08/2015   s1055  match_nonmatch
#
#                                           working_vol  \
# 0   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 1   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 2   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 3   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 4   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 5   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 6   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 7   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 8   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 9   /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 10  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 11  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 12  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 13  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 14  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 15  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 16  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 17  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 18  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 19  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 20  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 21  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 22  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 23  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 24  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 25  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 26  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 27  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 28  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 29  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 30  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 31  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 32  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 33  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 34  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 35  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 36  /media/tnaselar/Data/July_2015_preproc/s1055/P...
#
#                                            brain_mask  sessionID runType  \
# 0   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 1   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 2   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 3   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 4   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 5   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 6   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 7   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 8   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 9   /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 10  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 11  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 12  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     img
# 13  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 14  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 15  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 16  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 17  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 18  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 19  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 20  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 21  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 22  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 23  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     bar
# 24  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 25  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 26  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 27  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 28  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 29  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 30  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 31  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1   wedge
# 32  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 33  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 34  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 35  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 36  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
#
#    design matrix                frame_file            ...            vox_x  \
# 0           none      wedge_frame_file.txt            ...              0.8
# 1           none      wedge_frame_file.txt            ...              0.8
# 2           none        bar_frame_file.txt            ...              0.8
# 3           none        bar_frame_file.txt            ...              0.8
# 4           none        bar_frame_file.txt            ...              0.8
# 5           none                 run_0.txt            ...              0.8
# 6           none                 run_1.txt            ...              0.8
# 7           none                 run_2.txt            ...              0.8
# 8           none                 run_3.txt            ...              0.8
# 9           none                 run_6.txt            ...              0.8
# 10          none                 run_7.txt            ...              0.8
# 11          none                 run_4.txt            ...              0.8
# 12          none                 run_5.txt            ...              0.8
# 13          none      wedge_frame_file.txt            ...              0.8
# 14          none        bar_frame_file.txt            ...              0.8
# 15          none  spatial_freq_run_001.txt            ...              0.8
# 16          none  spatial_freq_run_002.txt            ...              0.8
# 17          none      wedge_frame_file.txt            ...              0.8
# 18          none        bar_frame_file.txt            ...              0.8
# 19          none  spatial_freq_run_002.txt            ...              0.8
# 20          none      wedge_frame_file.txt            ...              0.8
# 21          none      wedge_frame_file.txt            ...              0.8
# 22          none        bar_frame_file.txt            ...              0.8
# 23          none        bar_frame_file.txt            ...              0.8
# 24          none        mia_art_run_00.txt            ...              0.8
# 25          none        mia_art_run_01.txt            ...              0.8
# 26          none        mia_art_run_03.txt            ...              0.8
# 27          none        mia_art_run_04.txt            ...              0.8
# 28          none        mia_art_run_05.txt            ...              0.8
# 29          none        mia_art_run_06.txt            ...              0.8
# 30          none        mia_art_run_07.txt            ...              0.8
# 31          none      wedge_frame_file.txt            ...              0.8
# 32          none  spatial_freq_run_000.txt            ...              0.8
# 33          none  spatial_freq_run_003.txt            ...              0.8
# 34          none  spatial_freq_run_000.txt            ...              0.8
# 35          none  spatial_freq_run_001.txt            ...              0.8
# 36          none        mia_art_run_02.txt            ...              0.8
#
#     vox_y vox_z                                     run_code_path  \
# 0     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 1     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 2     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 3     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 4     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 5     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 6     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 7     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 8     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 9     0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 10    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 11    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 12    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 13    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 14    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 15    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 16    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 17    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 18    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 19    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 20    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 21    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 22    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 23    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 24    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 25    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 26    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 27    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 28    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 29    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 30    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 31    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 32    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 33    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 34    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 35    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 36    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
#
#         run_code_file  design_matrix_path  \
# 0   run_experiment.py                none
# 1   run_experiment.py                none
# 2   run_experiment.py                none
# 3   run_experiment.py                none
# 4   run_experiment.py                none
# 5   run_experiment.py                none
# 6   run_experiment.py                none
# 7   run_experiment.py                none
# 8   run_experiment.py                none
# 9   run_experiment.py                none
# 10  run_experiment.py                none
# 11  run_experiment.py                none
# 12  run_experiment.py                none
# 13  run_experiment.py                none
# 14  run_experiment.py                none
# 15  run_experiment.py                none
# 16  run_experiment.py                none
# 17  run_experiment.py                none
# 18  run_experiment.py                none
# 19  run_experiment.py                none
# 20  run_experiment.py                none
# 21  run_experiment.py                none
# 22  run_experiment.py                none
# 23  run_experiment.py                none
# 24  run_experiment.py                none
# 25  run_experiment.py                none
# 26  run_experiment.py                none
# 27  run_experiment.py                none
# 28  run_experiment.py                none
# 29  run_experiment.py                none
# 30  run_experiment.py                none
# 31  run_experiment.py                none
# 32  run_experiment.py                none
# 33  run_experiment.py                none
# 34  run_experiment.py                none
# 35  run_experiment.py                none
# 36  run_experiment.py                none
#
#                                         frameFilePath  \
# 0   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 1   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 2   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 3   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 4   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 5   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 6   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 7   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 8   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 9   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 10  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 11  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 12  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 13  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 14  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 15  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 16  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 17  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 18  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 19  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 20  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 21  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 22  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 23  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 24  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 25  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 26  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 27  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 28  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 29  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 30  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 31  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 32  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 33  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 34  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 35  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 36  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
#
#                                               picPath  siemensRef  padVol
# 0   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 1   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 2   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 3   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 4   /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 5   /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 6   /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 7   /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 8   /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 9   /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 10  /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 11  /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 12  /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....           0       0
# 13  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 14  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 15  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 16  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 17  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 18  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 19  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 20  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 21  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 22  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 23  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 24  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 25  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 26  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 27  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 28  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 29  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 30  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 31  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 32  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 33  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 34  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 35  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 36  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
#
# [37 rows x 29 columns]

# %% [markdown]
# ###Specify runs for training and testing the model

# %%
def select_run(row,runType):
    return row['runType'] in [runType]


art_runs = list(data_db[data_db.apply(select_run,axis=1,args=('art',))].runID)[0]
# freq_runs = list(data_db[data_db.apply(select_run,axis=1,args=('freq',))].runID)
# img_runs = list(data_db[data_db.apply(select_run,axis=1,args=('img',))].runID)[0]  ##<<this is the match/non-match

# %%
data_db.iloc[art_runs]
# Out:
#     runID        date subject      experiment  \
# 24     24  04/08/2015   s1055  match_nonmatch
# 25     25  04/08/2015   s1055  match_nonmatch
# 26     26  04/08/2015   s1055  match_nonmatch
# 27     27  04/08/2015   s1055  match_nonmatch
# 28     28  04/08/2015   s1055  match_nonmatch
# 29     29  04/08/2015   s1055  match_nonmatch
# 30     30  04/08/2015   s1055  match_nonmatch
# 36     36  04/08/2015   s1055  match_nonmatch
#
#                                           working_vol  \
# 24  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 25  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 26  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 27  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 28  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 29  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 30  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 36  /media/tnaselar/Data/July_2015_preproc/s1055/P...
#
#                                            brain_mask  sessionID runType  \
# 24  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 25  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 26  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 27  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 28  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 29  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 30  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
# 36  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1     art
#
#    design matrix          frame_file         ...         vox_x  vox_y vox_z  \
# 24          none  mia_art_run_00.txt         ...           0.8    0.8   0.8
# 25          none  mia_art_run_01.txt         ...           0.8    0.8   0.8
# 26          none  mia_art_run_03.txt         ...           0.8    0.8   0.8
# 27          none  mia_art_run_04.txt         ...           0.8    0.8   0.8
# 28          none  mia_art_run_05.txt         ...           0.8    0.8   0.8
# 29          none  mia_art_run_06.txt         ...           0.8    0.8   0.8
# 30          none  mia_art_run_07.txt         ...           0.8    0.8   0.8
# 36          none  mia_art_run_02.txt         ...           0.8    0.8   0.8
#
#                                        run_code_path      run_code_file  \
# 24  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 25  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 26  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 27  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 28  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 29  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 30  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
# 36  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation  run_experiment.py
#
#     design_matrix_path                                      frameFilePath  \
# 24                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 25                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 26                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 27                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 28                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 29                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 30                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 36                none  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
#
#                                               picPath  siemensRef  padVol
# 24  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 25  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 26  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 27  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 28  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 29  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 30  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 36  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
#
# [8 rows x 29 columns]

# %%
# data_db.iloc[freq_runs]
# Out:
#     runID        date subject      experiment  \
# 15     15  29/07/2015   s1055  match_nonmatch
# 16     16  29/07/2015   s1055  match_nonmatch
# 19     19  04/08/2015   s1055  match_nonmatch
# 32     32  29/07/2015   s1055  match_nonmatch
# 33     33  29/07/2015   s1055  match_nonmatch
# 34     34  04/08/2015   s1055  match_nonmatch
# 35     35  04/08/2015   s1055  match_nonmatch
#
#                                           working_vol  \
# 15  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 16  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 19  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 32  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 33  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 34  /media/tnaselar/Data/July_2015_preproc/s1055/P...
# 35  /media/tnaselar/Data/July_2015_preproc/s1055/P...
#
#                                            brain_mask  sessionID runType  \
# 15  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 16  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 19  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 32  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 33  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 34  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
# 35  /media/tnaselar/Data/July_2015_preproc/s1055/P...          1    freq
#
#    design matrix                frame_file            ...            vox_x  \
# 15          none  spatial_freq_run_001.txt            ...              0.8
# 16          none  spatial_freq_run_002.txt            ...              0.8
# 19          none  spatial_freq_run_002.txt            ...              0.8
# 32          none  spatial_freq_run_000.txt            ...              0.8
# 33          none  spatial_freq_run_003.txt            ...              0.8
# 34          none  spatial_freq_run_000.txt            ...              0.8
# 35          none  spatial_freq_run_001.txt            ...              0.8
#
#     vox_y vox_z                                     run_code_path  \
# 15    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 16    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 19    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 32    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 33    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 34    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# 35    0.8   0.8  /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
#
#         run_code_file  design_matrix_path  \
# 15  run_experiment.py                none
# 16  run_experiment.py                none
# 19  run_experiment.py                none
# 32  run_experiment.py                none
# 33  run_experiment.py                none
# 34  run_experiment.py                none
# 35  run_experiment.py                none
#
#                                         frameFilePath  \
# 15  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 16  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 19  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 32  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 33  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 34  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# 35  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
#
#                                               picPath  siemensRef  padVol
# 15  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 16  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 19  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 32  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 33  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 34  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
# 35  /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...           0       0
#
# [7 rows x 29 columns]

# %%
# data_db.iloc[img_runs]
# Out:
# runID                                                                 5
# date                                                         27/07/2015
# subject                                                           s1055
# experiment                                               match_nonmatch
# working_vol           /media/tnaselar/Data/July_2015_preproc/s1055/P...
# brain_mask            /media/tnaselar/Data/July_2015_preproc/s1055/P...
# sessionID                                                             1
# runType                                                             img
# design matrix                                                      none
# frame_file                                                    run_0.txt
# run_data_file         1_009_eja_ep2d_bold_p8iso_MB3_1p5sTR_R3_run00_...
# nvols                                                               209
# tesla                                                                7T
# location                                                        cmrr_ps
# run_path              /musc.repo/mri/7T.cmrr/July.2015/PS/nifti/Nase...
# TR                                                                  1.5
# matrix_x                                                            160
# matrix_y                                                            160
# n_slices                                                             66
# vox_x                                                               0.8
# vox_y                                                               0.8
# vox_z                                                               0.8
# run_code_path          /musc.repo/mri/7T.cmrr/July.2015/PS/presentation
# run_code_file                                         run_experiment.py
# design_matrix_path                                                 none
# frameFilePath         /musc.repo/mri/7T.cmrr/July.2015/PS/presentati...
# picPath               /musc.repo/mri/7T./musc.repo/mri/7T.cmrr/July....
# siemensRef                                                            0
# padVol                                                                0
# Name: 5, dtype: object

# %% [markdown]
# ###Load neural data

# %%
try:
    art_vols = preproc.load_runs(data_db,art_runs)
except: ##probably only one run
    art_runs = [art_runs]
    art_vols = preproc.load_runs(data_db,art_runs)
# freq_vols = preproc.load_runs(data_db,freq_runs)
# try:
#     img_vols = preproc.load_runs(data_db,img_runs)
# except: ##probably only one run
#     img_runs = [img_runs]
#     img_vols = preproc.load_runs(data_db,img_runs)
# Out:
# detrending run 0 with window_length: 105
# zscoring 0 thru 209

# %% [markdown]
# Reshape, mask, and remove inf's. Need to add this functionality to "load_runs"

# %%
##optional coronal slice selection
first_slice,last_slice = -25,-1

##first the mask. mucked up the database somehow, so reading in the brain mask is a stupid mess
bm = glob('/media'+data_db.iloc[img_runs[0]]['brain_mask'].split('/media')[2]+'/*.gz')
mask_image = nib.load(bm[0]).get_data().astype('bool') ##a numpy boolean

##now some indices for coronal slicing.
zdx = np.zeros(img_vols.shape[0:3]).astype('bool')
zdx[:,:,first_slice:last_slice] = True

##can't use any of the voxels with knackered values
finite_voxels = np.isfinite(img_vols.get_data()).all(axis=3)*np.isfinite(img_vols.get_data()).all(axis=3)

mask_image = mask_image*zdx*finite_voxels

# %%
def apply_mask(vol,raveled_mask):
    vol = vol.get_data().reshape((np.prod(vol.shape[0:3]),vol.shape[3])).T  ##converts to (time, xyz)
    return vol[:,raveled_mask]

# %%
##test masking
mean_vol = preproc.load_runs(data_db,img_runs[0:2],detrend=False,z_score=False)
mean_vol = apply_mask(mean_vol,mask_image.ravel()).mean(axis=0)
test_view = np.zeros(mask_image.shape).ravel()
test_view[mask_image.ravel()] = mean_vol
test_view = test_view.reshape(mask_image.shape)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.imshow(test_view[:,:,first_slice],cmap=cm.gray)
plt.subplot(1,2,2)
plt.imshow(test_view[:,:,last_slice-1],cmap=cm.gray)

# %%
# art_vols = apply_mask(art_vols,mask_image.ravel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-86a3f0a2e82f> in <module>()
# ----> 1 art_vols = apply_mask(art_vols,mask_image.ravel())
#
# NameError: name 'art_vols' is not defined

# %%
# print 'art_vols dimensions: %s' %(art_vols.shape,)

# %%
# freq_vols = apply_mask(freq_vols,mask_image.ravel())

# %%
# print 'freq_vols dimensions: %s' %(freq_vols.shape,)

# %%
img_vols = apply_mask(img_vols,mask_image.ravel())

# %%
print 'img_vols dimensions: %s' %(img_vols.shape,)
# Out:
# img_vols dimensions: (209, 165406)

# %% [markdown]
# ###Construct conditions matrices
# Note that chunkwise_downsampling not needed here because the chunksize is 1.

# %%
frame_lists = []
for _,row in data_db.iloc[img_runs].iterrows():
    frame_lists.append(preproc.load_frame_file(row))

# %%
##check
frame_lists[0][0:20]
# Out:
# ['isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'imagery_screen.png',
#  'southwest_003412_patch.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'imagery_screen.png',
#  'southeast_003277_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'imagery_screen.png',
#  'northwest_003167_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'imagery_screen.png']

# %% [markdown]
# The "imagery_screen" frame needs to be associated with a specific base/patch set. Do that processing here.

# %%
for run in frame_lists:
    for ii,frame in enumerate(run):
        if 'base' in frame:
            base = frame[:-8]
        if "imagery_screen" in frame:
            run[ii]=base+frame

# %% [markdown]
# The "patch" frames need to be labeled as "match" or "non-match". Do that processing here.

# %%
for run in frame_lists:
    for ii,frame in enumerate(run):
        if 'base' in frame:
            base = frame[:-8]
        if 'patch' in frame:
            if frame[:-9] == base:
                run[ii]='match_'+frame
            else:
                run[ii]='non_match_'+frame

# %%
frame_lists[0]
# Out:
# ['isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'southwest_003412_imagery_screen.png',
#  'match_southwest_003412_patch.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'southeast_003277_imagery_screen.png',
#  'match_southeast_003277_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'northwest_003167_imagery_screen.png',
#  'match_northwest_003167_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'southwest_003770_imagery_screen.png',
#  'non_match_southwest_003412_patch.png',
#  'isi_screen.png',
#  'northeast_004045_base.png',
#  'northeast_004045_imagery_screen.png',
#  'non_match_northeast_003860_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'southeast_003277_imagery_screen.png',
#  'match_southeast_003277_patch.png',
#  'isi_screen.png',
#  'northeast_003860_base.png',
#  'northeast_003860_imagery_screen.png',
#  'match_northeast_003860_patch.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'northwest_003167_imagery_screen.png',
#  'match_northwest_003167_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'southwest_003770_imagery_screen.png',
#  'match_southwest_003770_patch.png',
#  'isi_screen.png',
#  'northeast_003860_base.png',
#  'northeast_003860_imagery_screen.png',
#  'non_match_northeast_004045_patch.png',
#  'isi_screen.png',
#  'northeast_003860_base.png',
#  'northeast_003860_imagery_screen.png',
#  'match_northeast_003860_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'northwest_004001_base.png',
#  'northwest_004001_imagery_screen.png',
#  'non_match_northwest_003167_patch.png',
#  'isi_screen.png',
#  'northwest_004001_base.png',
#  'northwest_004001_imagery_screen.png',
#  'match_northwest_004001_patch.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'southeast_003277_imagery_screen.png',
#  'non_match_southeast_003067_patch.png',
#  'isi_screen.png',
#  'southeast_003067_base.png',
#  'southeast_003067_imagery_screen.png',
#  'non_match_southeast_003277_patch.png',
#  'isi_screen.png',
#  'northeast_004045_base.png',
#  'northeast_004045_imagery_screen.png',
#  'non_match_northeast_003860_patch.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'southeast_003277_imagery_screen.png',
#  'non_match_southeast_003067_patch.png',
#  'isi_screen.png',
#  'southeast_003067_base.png',
#  'southeast_003067_imagery_screen.png',
#  'non_match_southeast_003277_patch.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'southeast_003277_imagery_screen.png',
#  'match_southeast_003277_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'northwest_004001_base.png',
#  'northwest_004001_imagery_screen.png',
#  'match_northwest_004001_patch.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'southwest_003770_imagery_screen.png',
#  'non_match_southwest_003412_patch.png',
#  'isi_screen.png',
#  'southeast_003277_base.png',
#  'southeast_003277_imagery_screen.png',
#  'non_match_southeast_003067_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southeast_003067_base.png',
#  'southeast_003067_imagery_screen.png',
#  'match_southeast_003067_patch.png',
#  'isi_screen.png',
#  'northeast_004045_base.png',
#  'northeast_004045_imagery_screen.png',
#  'non_match_northeast_003860_patch.png',
#  'isi_screen.png',
#  'northeast_003860_base.png',
#  'northeast_003860_imagery_screen.png',
#  'match_northeast_003860_patch.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'southwest_003412_imagery_screen.png',
#  'non_match_southwest_003770_patch.png',
#  'isi_screen.png',
#  'northwest_004001_base.png',
#  'northwest_004001_imagery_screen.png',
#  'non_match_northwest_003167_patch.png',
#  'isi_screen.png',
#  'northeast_004045_base.png',
#  'northeast_004045_imagery_screen.png',
#  'match_northeast_004045_patch.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'southwest_003770_imagery_screen.png',
#  'non_match_southwest_003412_patch.png',
#  'isi_screen.png',
#  'northeast_004045_base.png',
#  'northeast_004045_imagery_screen.png',
#  'match_northeast_004045_patch.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'southwest_003412_imagery_screen.png',
#  'match_southwest_003412_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'southwest_003770_imagery_screen.png',
#  'match_southwest_003770_patch.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'southwest_003412_imagery_screen.png',
#  'non_match_southwest_003770_patch.png',
#  'isi_screen.png',
#  'northeast_004045_base.png',
#  'northeast_004045_imagery_screen.png',
#  'match_northeast_004045_patch.png',
#  'isi_screen.png',
#  'southwest_003770_base.png',
#  'southwest_003770_imagery_screen.png',
#  'match_southwest_003770_patch.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'northwest_003167_imagery_screen.png',
#  'non_match_northwest_004001_patch.png',
#  'isi_screen.png',
#  'southeast_003067_base.png',
#  'southeast_003067_imagery_screen.png',
#  'match_southeast_003067_patch.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'southwest_003412_imagery_screen.png',
#  'match_southwest_003412_patch.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'northwest_003167_imagery_screen.png',
#  'match_northwest_003167_patch.png',
#  'isi_screen.png',
#  'southwest_003412_base.png',
#  'southwest_003412_imagery_screen.png',
#  'non_match_southwest_003770_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'northeast_003860_base.png',
#  'northeast_003860_imagery_screen.png',
#  'non_match_northeast_004045_patch.png',
#  'isi_screen.png',
#  'northwest_004001_base.png',
#  'northwest_004001_imagery_screen.png',
#  'match_northwest_004001_patch.png',
#  'isi_screen.png',
#  'southeast_003067_base.png',
#  'southeast_003067_imagery_screen.png',
#  'non_match_southeast_003277_patch.png',
#  'isi_screen.png',
#  'northeast_003860_base.png',
#  'northeast_003860_imagery_screen.png',
#  'non_match_northeast_004045_patch.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'northwest_003167_imagery_screen.png',
#  'non_match_northwest_004001_patch.png',
#  'isi_screen.png',
#  'northwest_004001_base.png',
#  'northwest_004001_imagery_screen.png',
#  'non_match_northwest_003167_patch.png',
#  'isi_screen.png',
#  'northwest_003167_base.png',
#  'northwest_003167_imagery_screen.png',
#  'non_match_northwest_004001_patch.png',
#  'isi_screen.png',
#  'southeast_003067_base.png',
#  'southeast_003067_imagery_screen.png',
#  'match_southeast_003067_patch.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png',
#  'isi_screen.png']

# %%
condition_map, condition_sequence, condition_onsets,conditions_matrix = preproc.construct_conditions_matrix([it for fl in frame_lists for it in fl],1.5,10,not_a_condition =['isi_screen.png'])

# %%
print len(condition_sequence)
print len(condition_onsets)
# Out:
# 144
# 144

# %%
plt.plot(condition_onsets,condition_sequence)

# %%
sorted_cm = sorted(condition_map.items(), key=operator.itemgetter(1))
# condition_map
sorted_cm
# Out:
# [('southwest_003412_base.png', 0),
#  ('southwest_003412_imagery_screen.png', 1),
#  ('match_southwest_003412_patch.png', 2),
#  ('southeast_003277_base.png', 3),
#  ('southeast_003277_imagery_screen.png', 4),
#  ('match_southeast_003277_patch.png', 5),
#  ('northwest_003167_base.png', 6),
#  ('northwest_003167_imagery_screen.png', 7),
#  ('match_northwest_003167_patch.png', 8),
#  ('southwest_003770_base.png', 9),
#  ('southwest_003770_imagery_screen.png', 10),
#  ('non_match_southwest_003412_patch.png', 11),
#  ('northeast_004045_base.png', 12),
#  ('northeast_004045_imagery_screen.png', 13),
#  ('non_match_northeast_003860_patch.png', 14),
#  ('northeast_003860_base.png', 15),
#  ('northeast_003860_imagery_screen.png', 16),
#  ('match_northeast_003860_patch.png', 17),
#  ('match_southwest_003770_patch.png', 18),
#  ('non_match_northeast_004045_patch.png', 19),
#  ('northwest_004001_base.png', 20),
#  ('northwest_004001_imagery_screen.png', 21),
#  ('non_match_northwest_003167_patch.png', 22),
#  ('match_northwest_004001_patch.png', 23),
#  ('non_match_southeast_003067_patch.png', 24),
#  ('southeast_003067_base.png', 25),
#  ('southeast_003067_imagery_screen.png', 26),
#  ('non_match_southeast_003277_patch.png', 27),
#  ('match_southeast_003067_patch.png', 28),
#  ('non_match_southwest_003770_patch.png', 29),
#  ('match_northeast_004045_patch.png', 30),
#  ('non_match_northwest_004001_patch.png', 31)]

# %%
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
ax.imshow(conditions_matrix, cmap=cm.gray)
ax.set_aspect(1/6.)
print conditions_matrix.shape
# Out:
# (209, 320)

# %%
# we construct the matrix of drifts as the matrix of ones that account for
# the intercept term. If you have drifts estimated by e.g. SPM you can add
# them here.
drifts = np.ones((img_vols.shape[0], 1))

##fit this! 
hrfs, betas = he.glm(condition_sequence, condition_onsets, 1.5, img_vols, drifts=drifts, mode='r1glm', basis='3hrf', verbose=1)
# Out:
# .. creating design matrix ..
# .. done creating design matrix ..
# .. computing initialization ..
# .. done initialization ..
# .. completed 500 out of 165406 ..
# .. completed 1000 out of 165406 ..
# .. completed 1500 out of 165406 ..
# .. completed 2000 out of 165406 ..
# .. completed 2500 out of 165406 ..
# .. completed 3000 out of 165406 ..
# .. completed 3500 out of 165406 ..
# .. completed 4000 out of 165406 ..
# .. completed 4500 out of 165406 ..
# .. completed 5000 out of 165406 ..
# .. completed 5500 out of 165406 ..
# .. completed 6000 out of 165406 ..
# .. completed 6500 out of 165406 ..
# .. completed 7000 out of 165406 ..
# .. completed 7500 out of 165406 ..
# .. completed 8000 out of 165406 ..
# .. completed 8500 out of 165406 ..
# .. completed 9000 out of 165406 ..
# .. completed 142500 out of 165406 ..
# .. completed 143000 out of 165406 ..
# .. completed 143500 out of 165406 ..
# .. completed 144000 out of 165406 ..
# .. completed 144500 out of 165406 ..
# .. completed 145000 out of 165406 ..
# .. completed 145500 out of 165406 ..
# .. completed 146000 out of 165406 ..
# .. completed 146500 out of 165406 ..
# .. completed 147000 out of 165406 ..
# .. completed 147500 out of 165406 ..
# .. completed 148000 out of 165406 ..
# .. completed 148500 out of 165406 ..
# .. completed 149000 out of 165406 ..
# .. completed 149500 out of 165406 ..
# .. completed 150000 out of 165406 ..
# .. completed 150500 out of 165406 ..
# .. completed 151000 out of 165406 ..
# .. completed 151500 out of 165406 ..
# .. completed 152000 out of 165406 ..
# .. completed 152500 out of 165406 ..
# .. completed 153000 out of 165406 ..
# .. completed 153500 out of 165406 ..
# .. completed 154000 out of 165406 ..
# .. completed 154500 out of 165406 ..
# .. completed 155000 out of 165406 ..
# .. completed 155500 out of 165406 ..
# .. completed 156000 out of 165406 ..
# .. completed 156500 out of 165406 ..
# .. completed 157000 out of 165406 ..
# .. completed 157500 out of 165406 ..
# .. completed 158000 out of 165406 ..
# .. completed 158500 out of 165406 ..
# .. completed 159000 out of 165406 ..
# .. completed 159500 out of 165406 ..
# .. completed 160000 out of 165406 ..
# .. completed 160500 out of 165406 ..
# .. completed 161000 out of 165406 ..
# .. completed 161500 out of 165406 ..
# .. completed 162000 out of 165406 ..
# .. completed 162500 out of 165406 ..
# .. completed 163000 out of 165406 ..
# .. completed 163500 out of 165406 ..
# .. completed 164000 out of 165406 ..
# .. completed 164500 out of 165406 ..
# .. completed 165000 out of 165406 ..

# %%
print betas.shape
print hrfs.shape
# Out:
# (32, 165406)
# (3, 165406)

# %%
_=plt.hist(betas.ravel(),100,log=True)

# %%
xx = np.linspace(0, 25) # range of values for time
# construct the final HRF by multiplying by its basis
generated_hrfs = hrfs[0] * he.hrf.spmt(xx)[:, None] + hrfs[1] * he.hrf.dspmt(xx)[:, None] + hrfs[2] * he.hrf.ddspmt(xx)[:, None]

# %%
random_voxels = np.random.randint(0,high=hrfs.shape[1],size=100)
plt.figure(figsize=(12, 6))
plt.plot(xx, generated_hrfs[:,random_voxels])
plt.ylim((-.5, 1.))
plt.show()

# %%
brain_view = np.zeros(mask_image.shape).ravel()
brain_view[mask_image.ravel()] = mean_vol
brain_view = brain_view.reshape(mask_image.shape)

# %%
brain_view.shape
# Out:
# (160, 160, 66)

# %%
beta_view = np.zeros((mask_image.ravel().shape)+(betas.shape[0],))
print beta_view.shape
# Out:
# (1689600, 32)

# %%
for b in range(betas.shape[0]):
    beta_view[mask_image.ravel(),b] = betas[b,:].T

# %%
beta_view = beta_view.reshape(mask_image.shape+(betas.shape[0],))
print beta_view.shape
# Out:
# (160, 160, 66, 32)

# %%
##sanity check
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
plt.imshow(beta_view[:,:,64,1],cmap=cm.gray)
ax.set_aspect('equal')

# %%
nib.save(nib.Nifti1Image(brain_view,affine=np.eye(4)),'/media/tnaselar/Data/scratch/brain_beta_view.nii')

# %%
nib.save(nib.Nifti1Image(beta_view,affine=np.eye(4)),'/media/tnaselar/Data/scratch/beta_view.nii')
