# %% [markdown]
# ## Use feature-weighted rf model on the crcns vim-1 dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py
import pickle
from time import time
from glob import glob
from scipy.io import loadmat
from PIL import Image
from os.path import join
from scipy.stats import pearsonr
from hrf_fitting.src.feature_weighted_rf_models import make_rf_table,receptive_fields, model_space, prediction_menu, bigmult
from hrf_fitting.src.feature_weighted_rf_models import train_fwrf_model
from hrf_fitting.src.gabor_feature_dictionaries import gabor_feature_maps

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)

# %%
version_number = '1p1'

# %% [markdown]
# ### Step 0: Load crcns stimuli

# %% [markdown]
# #### load crcns stimuli

# %%
##known stimulus parameters
Ttrn = 1750
Tval = 120
S = 500
T = Ttrn+Tval
train_stim_files = glob('/media/tnaselar/Data/crcns_datasets/vim-1/Stimuli_Trn_FullRes*.mat')
val_stim_file = '/media/tnaselar/Data/crcns_datasets/vim-1/Stimuli_Val_FullRes.mat'
n_image_channels = 1 ##could be 3 for color images.

# %%
##allocate memory for stim
training_stim = np.zeros((Ttrn,S,S),dtype='float32')

##load training stim
cnt = 0
for sl in sorted(train_stim_files):
    this_h5 = h5py.File(sl,'r')
    this_train_stim = this_h5['stimTrn']
    this_num_stim = this_train_stim.shape[-1]
    training_stim[cnt:cnt+this_num_stim,:,:] = np.transpose(this_train_stim[:],[2,1,0])
    cnt += this_num_stim
    this_h5.close()
    
##load validation stim
val_h5 = h5py.File(val_stim_file,'r')
validation_stim = np.transpose(val_h5['stimVal'][:],[2,1,0])
val_h5.close()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.imshow(validation_stim[0,:,:],cmap='gray')
plt.subplot(1,2,2)
plt.imshow(training_stim[-1,:,:],cmap = 'gray')

# %% [markdown]
# ### Step 1: construct feature maps

# %%
n_orientations = 8
deg_per_stimulus = 20
lowest_sp_freq = .25 ##cyc/deg
highest_sp_freq = 6.25
num_sp_freq = 8
pix_per_cycle = 4#2.13333333
complex_cell = True

print 'D = total number of features = %d' %(n_orientations * num_sp_freq)
# Out:
# D = total number of features = 64

# %% [markdown]
# #### construct gabor wavelet stack

# %%
gfm = gabor_feature_maps(n_orientations,
                         deg_per_stimulus,
                         (lowest_sp_freq,highest_sp_freq,num_sp_freq),
                         pix_per_cycle=pix_per_cycle,complex_cell=complex_cell,
                         diams_per_filter = 4,
                        cycles_per_radius = 2.0)
# Out:
# /musc.repo/Docs/tnaselar/code/Python/hrf_fitting/src/gabor_feature_dictionaries.py:120: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   filter_stack = np.zeros((gbr_table.shape[0],color_channels,pix_per_filter,pix_per_filter))

# %%
gfm.gbr_table.head(9)
# Out:
#    cycles per deg.  cycles_per_filter  filter size (deg.)  pix per stimulus  \
# 0         0.250000                 16           64.000000         20.000000
# 1         0.395955                 16           40.408642         31.676392
# 2         0.627121                 16           25.513412         50.169691
# 3         0.993247                 16           16.108787         79.459740
# 4         1.573124                 16           10.170847        125.849895
# 5         2.491544                 16            6.421720        199.323532
# 6         3.946156                 16            4.054578        315.692518
# 7         6.250000                 16            2.560000        500.000000
# 8         0.250000                 16           64.000000         20.000000
#
#    pix_per_filter  radius of Gauss. envelope (deg)  orientation
# 0              64                         8.000000     0.000000
# 1              64                         5.051080     0.000000
# 2              64                         3.189177     0.000000
# 3              64                         2.013598     0.000000
# 4              64                         1.271356     0.000000
# 5              64                         0.802715     0.000000
# 6              64                         0.506822     0.000000
# 7              64                         0.320000     0.000000
# 8              64                         8.000000     0.392699

# %%
gfm.filter_stack.shape
# Out:
# (64, 1, 64, 64)

# %% [markdown]
# #### see one of the gabors

# %%
o =  8##choose an orientation
plt.imshow(np.imag(gfm.filter_stack[o,0,:,:]),cmap='gray')

# %% [markdown]
# ### Step 2: receptive fields

# %%
deg_per_radius = (.25, 8, 8) ##rf sizes in degrees (smallest, largest, number of sizes)
spacing = .75 ##spacing between rf's in degrees
rf = receptive_fields(deg_per_stimulus,deg_per_radius,spacing)

# %%
rf.rf_table.head()
# Out:
#    deg_per_radius  x_deg  y_deg
# 0            0.25  -10.0    -10
# 1            0.25   -9.2    -10
# 2            0.25   -8.4    -10
# 3            0.25   -7.6    -10
# 4            0.25   -6.8    -10

# %%
print 'G = number of rf models = %d' %(rf.rf_table.shape[0])
# Out:
# G = number of rf models = 5408

# %% [markdown]
# ### Step 3: Model space

# %% [markdown]
# #### apply an activation function

# %%
def log_act_func(x):
    return np.log(1+np.sqrt(x))

# %% [markdown]
# #### instantiate model space object

# %%
##construct the model space
init_feat_dict = gfm.create_feature_maps(training_stim[0,np.newaxis,np.newaxis,:,:])
ms = model_space(init_feat_dict, rf, activation_function = log_act_func)
# Out:
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.002116 s.
# feature 1 took 0.001991 s.
# feature 2 took 0.002935 s.
# feature 3 took 0.004991 s.
# feature 4 took 0.008690 s.
# feature 5 took 0.020253 s.
# feature 6 took 0.058358 s.
# feature 7 took 0.312057 s.
# feature 8 took 0.001501 s.
# feature 9 took 0.001936 s.
# feature 10 took 0.002805 s.
# feature 11 took 0.004816 s.
# feature 12 took 0.008512 s.
# feature 13 took 0.019206 s.
# feature 14 took 0.052931 s.
# feature 15 took 0.285131 s.
# feature 16 took 0.001511 s.
# feature 17 took 0.001925 s.
# feature 18 took 0.002825 s.
# feature 19 took 0.004799 s.
# feature 20 took 0.008560 s.
# feature 21 took 0.019645 s.
# feature 22 took 0.051275 s.
# feature 23 took 0.289172 s.
# feature 24 took 0.001509 s.
# feature 25 took 0.001936 s.
# feature 26 took 0.002837 s.
# feature 27 took 0.004851 s.
# feature 28 took 0.008544 s.
# feature 29 took 0.019810 s.
# feature 30 took 0.051504 s.
# feature 31 took 0.290529 s.
# feature 32 took 0.001545 s.
# feature 33 took 0.001918 s.
# feature 34 took 0.002802 s.
# feature 35 took 0.004827 s.
# feature 36 took 0.008566 s.
# feature 37 took 0.019626 s.
# feature 38 took 0.051247 s.
# feature 39 took 0.285748 s.
# feature 40 took 0.001502 s.
# feature 41 took 0.001930 s.
# feature 42 took 0.002843 s.
# feature 43 took 0.004812 s.
# feature 44 took 0.008524 s.
# feature 45 took 0.019193 s.
# feature 46 took 0.053538 s.
# feature 47 took 0.286946 s.
# feature 48 took 0.001531 s.
# feature 49 took 0.001937 s.
# feature 50 took 0.002813 s.
# feature 51 took 0.004888 s.
# feature 52 took 0.008591 s.
# feature 53 took 0.019290 s.
# feature 54 took 0.052589 s.
# feature 55 took 0.287336 s.
# feature 56 took 0.001510 s.
# feature 57 took 0.001921 s.
# feature 58 took 0.002766 s.
# feature 59 took 0.004858 s.
# feature 60 took 0.008601 s.
# feature 61 took 0.019811 s.
# feature 62 took 0.051218 s.
# feature 63 took 0.291801 s.

# %% [markdown]
# #### construct training/validation model space tensors

# %%
##loop over training stimuli because feature maps for all training stim. > 48Gb
training_mst = np.zeros((ms.receptive_fields.G, Ttrn, ms.D)).astype('float32')

num_chunks = 2
stim_dx = np.linspace(0,T-1,num=num_chunks+1, endpoint=True,dtype='int')

cnt = 0
for t in stim_dx[1:]:
    this_training_feature_dict = gfm.create_feature_maps(training_stim[cnt:cnt+t,np.newaxis,:,:])
    training_mst[:,cnt:cnt+t,:] = ms.construct_model_space_tensor(this_training_feature_dict,normalize=False)
    cnt += t

##clear up memory
this_training_feature_dict = []

##normalize and save normalization constants
training_mst = ms.normalize_model_space_tensor(training_mst, save=True)


##should work in one shot for because not too big
val_feature_dict = gfm.create_feature_maps(validation_stim[:,np.newaxis,:,:])
# Out:
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.502300 s.
# feature 1 took 0.913687 s.
# feature 2 took 1.986254 s.
# feature 3 took 3.611160 s.
# feature 4 took 6.905287 s.
# feature 5 took 16.241522 s.
# feature 6 took 46.543836 s.
# feature 7 took 280.319074 s.
# feature 8 took 0.529136 s.
# feature 9 took 0.936110 s.
# feature 10 took 2.049625 s.
# feature 11 took 3.691885 s.
# feature 12 took 7.086413 s.
# feature 13 took 16.188271 s.
# feature 14 took 46.714838 s.
# feature 15 took 296.638909 s.
# feature 16 took 0.508939 s.
# feature 17 took 0.921199 s.
# feature 18 took 1.993041 s.
# feature 19 took 3.616756 s.
# feature 20 took 6.911444 s.
# feature 21 took 16.246451 s.
# feature 22 took 46.842677 s.
# feature 23 took 217.377299 s.
# feature 24 took 0.521451 s.
# feature 25 took 0.973950 s.
# feature 26 took 2.044910 s.
# feature 27 took 3.717296 s.
# feature 28 took 7.050494 s.
# feature 29 took 16.550448 s.
# feature 30 took 44.632337 s.
# feature 31 took 165.974098 s.
# feature 32 took 0.520682 s.
# feature 33 took 0.942679 s.
# feature 34 took 2.035441 s.
# feature 35 took 3.711230 s.
# feature 36 took 7.102670 s.
# feature 37 took 16.671447 s.
# feature 38 took 44.913967 s.
# feature 39 took 171.014193 s.
# feature 40 took 0.518888 s.
# feature 41 took 0.938332 s.
# feature 42 took 2.036192 s.
# feature 43 took 3.706607 s.
# feature 44 took 7.058448 s.
# feature 45 took 16.540304 s.
# feature 46 took 45.010053 s.
# feature 47 took 165.476639 s.
# feature 48 took 0.520026 s.
# feature 49 took 0.938583 s.
# feature 50 took 2.033190 s.
# feature 51 took 3.689921 s.
# feature 52 took 7.056940 s.
# feature 53 took 16.548051 s.
# feature 54 took 44.924706 s.
# feature 55 took 206.476446 s.
# feature 56 took 0.512268 s.
# feature 57 took 0.923366 s.
# feature 58 took 2.004290 s.
# feature 59 took 3.658770 s.
# feature 60 took 6.960525 s.
# feature 61 took 16.224792 s.
# feature 62 took 47.187373 s.
# feature 63 took 205.715219 s.
# -----------feature: 0
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 1
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 2
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 3
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 4
# -----------feature: 5
# -----------feature: 6
# -----------feature: 7
# -----------feature: 8
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 9
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 10
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 11
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 12
# -----------feature: 13
# -----------feature: 14
# -----------feature: 15
# -----------feature: 16
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 17
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 18
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 19
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 20
# -----------feature: 21
# -----------feature: 22
# -----------feature: 23
# -----------feature: 24
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 25
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 26
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 27
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 28
# -----------feature: 29
# -----------feature: 30
# -----------feature: 31
# -----------feature: 32
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 33
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 34
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 35
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 36
# -----------feature: 37
# -----------feature: 38
# -----------feature: 39
# -----------feature: 40
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 41
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 42
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 43
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 44
# -----------feature: 45
# -----------feature: 46
# -----------feature: 47
# -----------feature: 48
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 49
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 50
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 51
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 52
# -----------feature: 53
# -----------feature: 54
# -----------feature: 55
# -----------feature: 56
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 57
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 58
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 59
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 60
# -----------feature: 61
# -----------feature: 62
# -----------feature: 63
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.441751 s.
# feature 1 took 0.802819 s.
# feature 2 took 1.754863 s.
# feature 3 took 3.165571 s.
# feature 4 took 6.059933 s.
# feature 5 took 14.084960 s.
# feature 6 took 40.675383 s.
# feature 7 took 155.813947 s.
# feature 8 took 0.452570 s.
# feature 9 took 0.818973 s.
# feature 10 took 1.776927 s.
# feature 11 took 3.228760 s.
# feature 12 took 6.174184 s.
# feature 13 took 14.394439 s.
# feature 14 took 39.268552 s.
# feature 15 took 144.758916 s.
# feature 16 took 0.455558 s.
# feature 17 took 0.823367 s.
# feature 18 took 1.778471 s.
# feature 19 took 3.228735 s.
# feature 20 took 6.177540 s.
# feature 21 took 14.417985 s.
# feature 22 took 39.229286 s.
# feature 23 took 144.629308 s.
# feature 24 took 0.456024 s.
# feature 25 took 0.820377 s.
# feature 26 took 1.776427 s.
# feature 27 took 3.229923 s.
# feature 28 took 6.176990 s.
# feature 29 took 14.382997 s.
# feature 30 took 39.280633 s.
# feature 31 took 144.663983 s.
# feature 32 took 0.454821 s.
# feature 33 took 0.821698 s.
# feature 34 took 1.778202 s.
# feature 35 took 3.228029 s.
# feature 36 took 6.176875 s.
# feature 37 took 14.398294 s.
# feature 38 took 39.256992 s.
# feature 39 took 144.455535 s.
# feature 40 took 0.457243 s.
# feature 41 took 0.821163 s.
# feature 42 took 1.778355 s.
# feature 43 took 3.228562 s.
# feature 44 took 6.229590 s.
# feature 45 took 14.416655 s.
# feature 46 took 39.150947 s.
# feature 47 took 144.251684 s.
# feature 48 took 0.457205 s.
# feature 49 took 0.821950 s.
# feature 50 took 1.775502 s.
# feature 51 took 3.224903 s.
# feature 52 took 6.172178 s.
# feature 53 took 14.401637 s.
# feature 54 took 39.149033 s.
# feature 55 took 143.868336 s.
# feature 56 took 0.455339 s.
# feature 57 took 0.820359 s.
# feature 58 took 1.775338 s.
# feature 59 took 3.226246 s.
# feature 60 took 6.171414 s.
# feature 61 took 14.386897 s.
# feature 62 took 39.175391 s.
# feature 63 took 143.860866 s.
# -----------feature: 0
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 1
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 2
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 3
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 4
# -----------feature: 5
# -----------feature: 6
# -----------feature: 7
# -----------feature: 8
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 9
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 10
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 11
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 12
# -----------feature: 13
# -----------feature: 14
# -----------feature: 15
# -----------feature: 16
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 17
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 18
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 19
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 20
# -----------feature: 21
# -----------feature: 22
# -----------feature: 23
# -----------feature: 24
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 25
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 26
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 27
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 28
# -----------feature: 29
# -----------feature: 30
# -----------feature: 31
# -----------feature: 32
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 33
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 34
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 35
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 36
# -----------feature: 37
# -----------feature: 38
# -----------feature: 39
# -----------feature: 40
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 41
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 42
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 43
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 44
# -----------feature: 45
# -----------feature: 46
# -----------feature: 47
# -----------feature: 48
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 49
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 50
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 51
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 52
# -----------feature: 53
# -----------feature: 54
# -----------feature: 55
# -----------feature: 56
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 57
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 58
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 59
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 60
# -----------feature: 61
# -----------feature: 62
# -----------feature: 63
# normalization constants have been saved
# converted nans to nums
# model_space_tensor has been z-scored
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.806871 s.
# feature 1 took 0.880530 s.
# feature 2 took 1.011045 s.
# feature 3 took 1.215078 s.
# feature 4 took 1.649426 s.
# feature 5 took 2.854073 s.
# feature 6 took 6.454020 s.
# feature 7 took 21.789205 s.
# feature 8 took 0.818268 s.
# feature 9 took 0.884462 s.
# feature 10 took 1.005621 s.
# feature 11 took 1.268790 s.
# feature 12 took 1.703674 s.
# feature 13 took 2.881594 s.
# feature 14 took 6.493163 s.
# feature 15 took 21.682896 s.
# feature 16 took 0.809437 s.
# feature 17 took 0.859715 s.
# feature 18 took 1.008094 s.
# feature 19 took 1.220490 s.
# feature 20 took 1.654670 s.
# feature 21 took 2.861221 s.
# feature 22 took 6.494968 s.
# feature 23 took 21.674275 s.
# feature 24 took 0.804786 s.
# feature 25 took 0.867077 s.
# feature 26 took 1.000315 s.
# feature 27 took 1.222285 s.
# feature 28 took 1.651393 s.
# feature 29 took 2.861383 s.
# feature 30 took 6.512735 s.
# feature 31 took 21.828664 s.
# feature 32 took 0.808379 s.
# feature 33 took 0.870875 s.
# feature 34 took 1.013341 s.
# feature 35 took 1.227092 s.
# feature 36 took 1.666532 s.
# feature 37 took 2.874796 s.
# feature 38 took 6.520306 s.
# feature 39 took 21.836831 s.
# feature 40 took 0.805605 s.
# feature 41 took 0.868233 s.
# feature 42 took 1.000567 s.
# feature 43 took 1.220922 s.
# feature 44 took 1.657354 s.
# feature 45 took 2.868160 s.
# feature 46 took 6.502384 s.
# feature 47 took 21.861622 s.
# feature 48 took 0.818314 s.
# feature 49 took 0.867064 s.
# feature 50 took 1.010919 s.
# feature 51 took 1.219601 s.
# feature 52 took 1.657515 s.
# feature 53 took 2.869329 s.
# feature 54 took 6.537138 s.
# feature 55 took 21.850517 s.
# feature 56 took 0.806854 s.
# feature 57 took 0.867851 s.
# feature 58 took 1.003022 s.
# feature 59 took 1.223547 s.
# feature 60 took 1.654800 s.
# feature 61 took 2.869309 s.
# feature 62 took 6.523927 s.
# feature 63 took 21.841054 s.

# %%
validation_mst = ms.construct_model_space_tensor(val_feature_dict,normalize=True)
# Out:
# -----------feature: 0
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 1
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 2
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 3
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 4
# -----------feature: 5
# -----------feature: 6
# -----------feature: 7
# -----------feature: 8
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 9
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 10
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 11
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 12
# -----------feature: 13
# -----------feature: 14
# -----------feature: 15
# -----------feature: 16
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 17
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 18
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 19
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 20
# -----------feature: 21
# -----------feature: 22
# -----------feature: 23
# -----------feature: 24
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 25
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 26
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 27
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 28
# -----------feature: 29
# -----------feature: 30
# -----------feature: 31
# -----------feature: 32
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 33
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 34
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 35
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 36
# -----------feature: 37
# -----------feature: 38
# -----------feature: 39
# -----------feature: 40
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 41
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 42
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 43
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 44
# -----------feature: 45
# -----------feature: 46
# -----------feature: 47
# -----------feature: 48
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 49
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 50
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 51
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 52
# -----------feature: 53
# -----------feature: 54
# -----------feature: 55
# -----------feature: 56
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 57
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 58
# at pixel resolution 50 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 59
# at pixel resolution 79 the following rfs will default to 0: (array([ 0.25]),)
# -----------feature: 60
# -----------feature: 61
# -----------feature: 62
# -----------feature: 63
# converted nans to nums
# model_space_tensor has been z-scored

# %% [markdown]
# ### Step 4: load data and fit models in a loop

# %%
def save_stuff(save_to_this_file, data_objects_dict):
    failed = []
    with h5py.File(save_to_this_file+'.h5py', 'w') as hf:
        for k,v in data_objects_dict.iteritems():
            try:
                hf.create_dataset(k,data=v)
                print 'saved %s in h5py file' %(k)
            except:
                failed.append(k)
                print 'failed to save %s as h5py. will try pickle' %(k)
    
    for k in failed:
        with open(save_to_this_file+'_'+'%s.pkl' %(k), 'w') as pkl:
            try:
                pickle.dump(data_objects_dict[k],pkl)
                print 'saved %s as pkl' %(k)
            except:
                print 'failed to save %s in any format. lost.' %(k)

# %%
subjects = ['S1','S2']
saving_dir = '/media/tnaselar/Data/fwrf/Gabor_model/'
voxel_file = '/media/tnaselar/Data/crcns_datasets/vim-1/EstimatedResponses.mat'
# Out:
# [u'dataTrnS1',
#  u'dataTrnS2',
#  u'dataValS1',
#  u'dataValS2',
#  u'roiS1',
#  u'roiS2',
#  u'voxIdxS1',
#  u'voxIdxS2']

# %%
with  h5py.File(voxel_file,'r') as crcns_voxel_data:
    for subj in subjects:
        saving_file = join(saving_dir, 'gabor_model_%s' %(subj))
        save_this_data = {}
        save_this_data['model_space'] = ms
        #remove nans, becuase this data-set has some. otherwise even one nan will infect gradient for every voxel.
        voxel_data = np.concatenate((crcns_voxel_data['dataVal'+subj],crcns_voxel_data['dataTrn'+subj])
                                    ,axis=0).astype('float32')
        no_nan = np.isnan(voxel_data).sum(axis=0) == 0 ##<<pull voxels with nans 
        voxel_data = voxel_data[:,no_nan]
        print voxel_data.shape
        V = voxel_data.shape[1]
        #get training/validation views on voxel_data
        nvox=V
        trnIdx = np.arange(Tval,T)
        valIdx = np.arange(0,Tval)
        trn_voxel_data = voxel_data[trnIdx,0:nvox]
        val_voxel_data = voxel_data[valIdx,0:nvox]
        #train the model!
        fvl,ffw,frf,beh = train_fwrf_model(training_mst,
                                           trn_voxel_data,
                                           initial_feature_weights='zeros',
                                           voxel_binsize = nvox,
                                           rf_grid_binsize=10,
                                           learning_rate=10**(-5.3),
                                           max_iters = 200,
                                           early_stop_fraction=0.2,
                                           report_every = 100)
                                           
                                          

        save_this_data['fvl'] = fvl
        save_this_data['ffw'] = ffw
        save_this_data['frf'] = frf
        save_this_data['beh'] = beh

        ##generate predictions one voxel at a time
        pred = np.zeros((Tval,nvox))
        for v in range(nvox):  ##<<some kind of bug in training function, last voxel getting skipped.
            pred[:,v] = np.squeeze(bigmult(validation_mst[np.newaxis,frf[v],:,:],
                                           ffw[np.newaxis,:,v, np.newaxis]))
        save_this_data['pred'] = pred

        ##get correlation = prediction accuracy
        val_cc = np.zeros(nvox)  
        for v in range(nvox): 
            val_cc[v] = pearsonr(val_voxel_data[:,v],pred[:,v])[0]
        val_cc = np.nan_to_num(val_cc)
        save_this_data['val_cc'] = val_cc

        save_stuff(saving_file, {})
# Out:
# (1870, 22701)
# --------------voxels from 0 to 22701
# --------candiate rf models 0 to 10
# -------
# errors: 351.187756
# change in best rf: 107124.000000
# norm of feature weights: 1.268430
# improvements: 227010
# 0.316738843918
# -------
# errors: 349.517910
# change in best rf: -41.000000
# norm of feature weights: 41.282078
# improvements: 37127
# 25.4349689484
# --------candiate rf models 10 to 20
# -------
# errors: 351.205841
# change in best rf: 99052.000000
# norm of feature weights: 1.358092
# improvements: 227010
# 0.307096004486
# -------
# errors: 349.604262
# change in best rf: 15.000000
# norm of feature weights: 42.759632
# improvements: 34965
# 25.2870190144
# --------candiate rf models 20 to 30
# -------
# errors: 351.184034
# change in best rf: 106503.000000
# norm of feature weights: 1.237473
# improvements: 227010
# 0.307070016861
# -------
# errors: 349.698793
# change in best rf: -60.000000
# norm of feature weights: 39.028313
# improvements: 33934
# 25.2100629807
# --------candiate rf models 30 to 40
# -------
# errors: 351.179812
# change in best rf: 96867.000000
# norm of feature weights: 1.388538
# improvements: 227010
# 0.308877944946
# -------
# errors: 349.552031
# change in best rf: -2.000000
# norm of feature weights: 42.319740
# improvements: 36838
# 25.3546538353
# --------candiate rf models 40 to 50
# -------
# errors: 351.200277
# change in best rf: 105046.000000
# norm of feature weights: 1.335356
# improvements: 227010
# 0.307184934616
# -------
# errors: 349.732584
# change in best rf: -4.000000
# norm of feature weights: 42.316189
# improvements: 34098
# 25.3325190544
# --------candiate rf models 50 to 60
# -------
# errors: 351.162723
# change in best rf: 93438.000000
# norm of feature weights: 1.305085
# improvements: 227010
# 0.307879924774
# -------
# errors: 349.564081
# change in best rf: -25.000000
# norm of feature weights: 41.055649
# improvements: 33351
# 25.1945059299
# --------candiate rf models 60 to 70
# -------
# errors: 351.154474
# change in best rf: 103221.000000
# norm of feature weights: 1.425283
# improvements: 227010
# 0.306059122086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-7201c518cf88> in <module>()
#      26                                            max_iters = 200,
#      27                                            early_stop_fraction=0.2,
# ---> 28                                            report_every = 100)
#      29
#      30
#
# /musc.repo/Docs/tnaselar/code/Python/hrf_fitting/src/feature_weighted_rf_models.pyc in train_fwrf_model(model_space_tensor, voxel_data, initial_feature_weights, early_stop_fraction, max_iters, mini_batch_size, learning_rate, voxel_binsize, rf_grid_binsize, report_every)
#     495
#     496                 ##updated loss
# --> 497                 this_validation_loss = sq_diff_func(this_val_voxel_data, pm)
#     498
#     499                 ##if new loss minimum, save as best
#
# /home/tnaselar/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     897         try:
#     898             outputs =\
# --> 899                 self.fn() if output_subset is None else\
#     900                 self.fn(output_subset=output_subset)
#     901         except Exception:
#
# KeyboardInterrupt:

# %%
##close data file
crcns_voxel_data.close()
