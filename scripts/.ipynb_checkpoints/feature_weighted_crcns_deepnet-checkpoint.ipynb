# %% [markdown]
# ## Glue deepnet to crcns data using the feature-weighted rf model

# %%
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from time import time
from glob import glob
from scipy.io import loadmat
from PIL import Image
from scipy.stats import pearsonr
from hrf_fitting.src.feature_weighted_rf_models import make_rf_table,receptive_fields, model_space, prediction_menu,bigmult
from hrf_fitting.src.feature_weighted_rf_models import train_fwrf_model
from hrf_fitting.src.gabor_feature_dictionaries import gabor_feature_maps

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN X

# %% [markdown]
# ### Step 0: Load crcns feature maps

# %%
##known stimulus parameters
Ttrn = 1750
Tval = 120

##don't use these
junk_keys = ['__header__', '__globals__', '__version__', 'fc6', 'fc7', 'fc8','prob']

##this is > 8GB
deepnet_trn_feature_dict = loadmat('/media/tnaselar/Data/deepnet_vim-1/vim-1_trn_response.mat')
##it contains some key/value pairs we don't want

deepnet_trn_feature_dict = {key: value.astype('float32') for key, value in deepnet_trn_feature_dict.items() if key not in junk_keys}
print deepnet_trn_feature_dict.keys()

##much smaller
deepnet_val_feature_dict = loadmat('/media/tnaselar/Data/deepnet_vim-1/vim-1_val_response.mat')
##it contains some key/value pairs we don't want
deepnet_val_feature_dict = {key: value.astype('float32') for key, value in deepnet_val_feature_dict.items() if key not in junk_keys}
print deepnet_val_feature_dict.keys()
# Out:
# ['conv3', 'conv2', 'conv1', 'conv5', 'conv4']
# ['conv3', 'conv2', 'conv1', 'conv5', 'conv4']

# %% [markdown]
# ### Step 2: receptive fields

# %%
deg_per_stimulus = 20
deg_per_radius = (1.5, 5, 4) ##rf sizes in degrees (smallest, largest, number of sizes)
spacing = 2.5 ##spacing between rf's in degrees
rf = receptive_fields(deg_per_stimulus,deg_per_radius,spacing)

# %%
rf.rf_table.head()
# Out:
#    deg_per_radius      x_deg  y_deg
# 0             1.5 -10.000000    -10
# 1             1.5  -7.142857    -10
# 2             1.5  -4.285714    -10
# 3             1.5  -1.428571    -10
# 4             1.5   1.428571    -10

# %%
print 'G = number of rf models = %d' %(rf.rf_table.shape[0])
# Out:
# G = number of rf models = 256

# %% [markdown]
# ### Step 3: Model space

# %% [markdown]
# #### instantiate model space object

# %%
print deepnet_trn_feature_dict['conv5'].shape
# Out:
# (1750, 256, 13, 13)

# %%
##construct the model space, add a bias feature (all 1's)
ms = model_space(deepnet_trn_feature_dict, rf, add_bias=True)

# %%
ms.feature_resolutions
# Out:
# {'bias': 0, 'conv1': 55, 'conv2': 27, 'conv3': 13, 'conv4': 13, 'conv5': 13}

# %%
ms.D*ms.receptive_fields.G*1750/1024./1024./1024.*4
# Out:
# 2.2981166839599609

# %%
deepnet_trn_feature_dict['conv1'].dtype
# Out:
# dtype('float32')

# %% [markdown]
# #### construct training/validation model space tensors

# %%
##training data
trn_mst = ms.construct_model_space_tensor(deepnet_trn_feature_dict,normalize=False)

##normalize and save normalization constants
trn_mst = ms.normalize_model_space_tensor(trn_mst, save=True)
# Out:
# -----------feature: conv3
# at pixel resolution 13 the following rfs will default to 0: (array([ 1.5]),)
# -----------feature: conv2
# -----------feature: conv1
# -----------feature: conv5
# at pixel resolution 13 the following rfs will default to 0: (array([ 1.5]),)
# -----------feature: conv4
# at pixel resolution 13 the following rfs will default to 0: (array([ 1.5]),)
# normalization constants have been saved
# model_space_tensor has been z-scored

# %%
##validation data
val_mst = ms.construct_model_space_tensor(deepnet_val_feature_dict)
# Out:
# -----------feature: conv3
# at pixel resolution 13 the following rfs will default to 0: (array([ 1.5]),)
# -----------feature: conv2
# -----------feature: conv1
# -----------feature: conv5
# at pixel resolution 13 the following rfs will default to 0: (array([ 1.5]),)
# -----------feature: conv4
# at pixel resolution 13 the following rfs will default to 0: (array([ 1.5]),)
# model_space_tensor has been z-scored

# %%
del deepnet_trn_feature_dict
del deepnet_val_feature_dict

# %% [markdown]
# ### Step 4: load and package crcns voxel data

# %%
voxel_file = '/media/tnaselar/Data/crcns_datasets/vim-1/EstimatedResponses.mat'
crcns_voxel_data = h5py.File(voxel_file,'r')
crcns_voxel_data.keys()
# Out:
# [u'dataTrnS1',
#  u'dataTrnS2',
#  u'dataValS1',
#  u'dataValS2',
#  u'roiS1',
#  u'roiS2',
#  u'voxIdxS1',
#  u'voxIdxS2']

# %% [markdown]
# #### remove nans, becuase this data-set has some. otherwise even one nan will infect gradient for every voxel.

# %%
voxel_data = np.concatenate((crcns_voxel_data['dataValS1'],crcns_voxel_data['dataTrnS1']),axis=0).astype('float32')
no_nan = np.isnan(voxel_data).sum(axis=0) == 0 ##<<only pulled voxels with nans in training data, should pull if nans in val data too.
voxel_data = voxel_data[:,no_nan]
print voxel_data.shape
V = voxel_data.shape[1]
# Out:
# (1870, 22701)

# %%
crcns_voxel_data.close()

# %% [markdown]
# #### get training/validation views on voxel_data

# %%
T = Tval+Ttrn
nvox= V
trnIdx = np.arange(Tval,T)
valIdx = np.arange(0,Tval)
trn_voxel_data = voxel_data[trnIdx,0:nvox]

# %% [markdown]
# ### Step 5: run that shit.

# %% [markdown]
# #### initialize the feature weights

# %%
initial_feature_weights = np.zeros((ms.receptive_fields.G,ms.D,V),dtype='float32')

# %% [markdown]
# #### train the model!

# %%
fvl,ffw,frf,beh = train_fwrf_model(trn_mst,
                 trn_voxel_data,
                 initial_feature_weights,
                 voxel_binsize = nvox,
                 rf_grid_binsize=10,
                 learning_rate=10**(-7.0),
                 max_iters = 50,
                 early_stop_fraction=0.2,
                 report_every = 25)
# Out:
# --------------voxels from 0 to 22699
# --------candiate rf models 0 to 10
# -------
# errors: 348.309955
# change in best rf: 118655.000000
# norm of feature weights: 0.081097
# improvements: 249700
# 6.54844498634
# -------
# errors: 347.402514
# change in best rf: 178.000000
# norm of feature weights: 1.761292
# improvements: 110755
# 141.550207138
# --------candiate rf models 10 to 20
# -------
# errors: 348.307679
# change in best rf: 114441.000000
# norm of feature weights: 0.082664
# improvements: 249700
# 6.49432492256
# -------
# errors: 347.233027
# change in best rf: 251.000000
# norm of feature weights: 1.884574
# improvements: 117153
# 142.215080976
# --------candiate rf models 21 to 31
# -------
# errors: 348.304186
# change in best rf: 110887.000000
# norm of feature weights: 0.083546
# improvements: 249700
# 6.47421717644
# -------
# errors: 347.049088
# change in best rf: -13.000000
# norm of feature weights: 1.949634
# improvements: 119560
# 141.280495882
# --------candiate rf models 31 to 41
# -------
# errors: 348.306619
# change in best rf: 107602.000000
# norm of feature weights: 0.081507
# improvements: 249700
# 6.49215912819
# -------
# errors: 347.073670
# change in best rf: -16.000000
# norm of feature weights: 1.917858
# improvements: 117441
# 141.460286856
# --------candiate rf models 42 to 52
# -------
# errors: 348.317322
# change in best rf: 108597.000000
# norm of feature weights: 0.078468
# improvements: 249700
# 6.44921302795
# -------
# errors: 347.296864
# change in best rf: -64.000000
# norm of feature weights: 1.844601
# improvements: 119420
# 141.202928066
# --------candiate rf models 53 to 63
# -------
# errors: 348.326665
# change in best rf: 106236.000000
# norm of feature weights: 0.075459
# improvements: 249700
# 6.49021697044
# -------
# errors: 347.569570
# change in best rf: -143.000000
# norm of feature weights: 1.701121
# improvements: 110599
# 141.142712831
# --------candiate rf models 63 to 73
# -------
# errors: 348.195412
# change in best rf: 114560.000000
# norm of feature weights: 0.157960
# improvements: 249700
# 6.51564908028
# -------
# errors: 346.292399
# change in best rf: -195.000000
# norm of feature weights: 3.283985
# improvements: 93808
# 140.598471165
# --------candiate rf models 74 to 84
# -------
# errors: 348.172699
# change in best rf: 122972.000000
# norm of feature weights: 0.169327
# improvements: 249700
# 6.53595399857
# -------
# errors: 345.827294
# change in best rf: -36.000000
# norm of feature weights: 3.597829
# improvements: 98539
# 141.290042877
# --------candiate rf models 85 to 95
# -------
# errors: 348.157308
# change in best rf: 111939.000000
# norm of feature weights: 0.171188
# improvements: 249700
# 6.48465299606
# -------
# errors: 345.381912
# change in best rf: 56.000000
# norm of feature weights: 3.717533
# improvements: 100492
# 141.274331093
# --------candiate rf models 95 to 105
# -------
# errors: 348.162930
# change in best rf: 106649.000000
# norm of feature weights: 0.168956
# improvements: 249700
# 6.50763511658
# -------
# errors: 345.375402
# change in best rf: -27.000000
# norm of feature weights: 3.710186
# improvements: 99612
# 141.404510975
# --------candiate rf models 106 to 116
# -------
# errors: 348.197076
# change in best rf: 106163.000000
# norm of feature weights: 0.163283
# improvements: 249700
# 6.50727415085
# -------
# errors: 345.877667
# change in best rf: 42.000000
# norm of feature weights: 3.602919
# improvements: 99817
# 141.772351027
# --------candiate rf models 116 to 126
# -------
# errors: 348.232306
# change in best rf: 103535.000000
# norm of feature weights: 0.156206
# improvements: 249700
# 6.4963080883
# -------
# errors: 346.505826
# change in best rf: -8.000000
# norm of feature weights: 3.418877
# improvements: 94999
# 140.857053995
# --------candiate rf models 127 to 137
# -------
# errors: 348.167373
# change in best rf: 101191.000000
# norm of feature weights: 0.168572
# improvements: 249700
# 6.5189101696
# -------
# errors: 346.007882
# change in best rf: -6.000000
# norm of feature weights: 3.462995
# improvements: 94495
# 141.054559946
# --------candiate rf models 138 to 148
# -------
# errors: 348.162742
# change in best rf: 125765.000000
# norm of feature weights: 0.175706
# improvements: 249700
# 6.4199590683
# -------
# errors: 345.873110
# change in best rf: -52.000000
# norm of feature weights: 3.639364
# improvements: 98819
# 141.125010014
# --------candiate rf models 148 to 158
# -------
# errors: 348.148398
# change in best rf: 113313.000000
# norm of feature weights: 0.178278
# improvements: 249700
# 6.51040887833
# -------
# errors: 345.540761
# change in best rf: 56.000000
# norm of feature weights: 3.748003
# improvements: 101045
# 141.719084978
# --------candiate rf models 159 to 169
# -------
# errors: 348.153189
# change in best rf: 106010.000000
# norm of feature weights: 0.175382
# improvements: 249700
# 6.50648093224
# -------
# errors: 345.504216
# change in best rf: 170.000000
# norm of feature weights: 3.735569
# improvements: 100034
# 141.518869162
# --------candiate rf models 170 to 180
# -------
# errors: 348.184025
# change in best rf: 105142.000000
# norm of feature weights: 0.170171
# improvements: 249700
# 6.5150539875
# -------
# errors: 345.900024
# change in best rf: 161.000000
# norm of feature weights: 3.652132
# improvements: 100214
# 141.530843019
# --------candiate rf models 180 to 190
# -------
# errors: 348.219635
# change in best rf: 97007.000000
# norm of feature weights: 0.162467
# improvements: 249700
# 6.50136017799
# -------
# errors: 346.414457
# change in best rf: 73.000000
# norm of feature weights: 3.499775
# improvements: 97362
# 141.134708166
# --------candiate rf models 191 to 201
# -------
# errors: 348.157625
# change in best rf: 99465.000000
# norm of feature weights: 0.173769
# improvements: 249700
# 6.43459510803
# -------
# errors: 345.895858
# change in best rf: 63.000000
# norm of feature weights: 3.536777
# improvements: 96363
# 140.956429005
# --------candiate rf models 201 to 211
# -------
# errors: 348.163338
# change in best rf: 132838.000000
# norm of feature weights: 0.179541
# improvements: 249700
# 6.44980287552
# -------
# errors: 345.995047
# change in best rf: -64.000000
# norm of feature weights: 3.660843
# improvements: 98814
# 140.817276001
# --------candiate rf models 212 to 222
# -------
# errors: 348.151713
# change in best rf: 111823.000000
# norm of feature weights: 0.182045
# improvements: 249700
# 6.45808005333
# -------
# errors: 345.748861
# change in best rf: -28.000000
# norm of feature weights: 3.749404
# improvements: 100767
# 140.589697838
# --------candiate rf models 223 to 233
# -------
# errors: 348.154153
# change in best rf: 105358.000000
# norm of feature weights: 0.179638
# improvements: 249700
# 6.51312589645
# -------
# errors: 345.692001
# change in best rf: -81.000000
# norm of feature weights: 3.743545
# improvements: 100120
# 141.768918037
# --------candiate rf models 233 to 243
# -------
# errors: 348.177308
# change in best rf: 111894.000000
# norm of feature weights: 0.175749
# improvements: 249700
# 6.45112705231
# -------
# errors: 345.960512
# change in best rf: 50.000000
# norm of feature weights: 3.691353
# improvements: 100116
# 141.177176952
# --------candiate rf models 244 to 254
# -------
# errors: 348.208476
# change in best rf: 92710.000000
# norm of feature weights: 0.168503
# improvements: 249700
# 6.51538014412
# -------
# errors: 346.348878
# change in best rf: 131.000000
# norm of feature weights: 3.574587
# improvements: 98998
# 141.325738907
# 6773.99670601

# %%
pdb

# %% [markdown]
# #### loss histories, all voxels

# %%
_=plt.plot(beh-beh[0,:])

# %% [markdown]
# #### view loss history for a few voxels

# %%
_=plt.plot(beh[:,slice(0,-1,600)]-beh[0,slice(0,-1,600)])

# %%
##loss in "final_validation_loss" = last point of "best_error_history"
print np.min(beh[:,-2])
print fvl[-2]

# %% [markdown]
# #### diff between first and last point of loss history, all voxels

# %%
_=plt.hist(beh[0,:]-np.min(beh,axis=0),100)
plt.yscale('log')

# %% [markdown]
# ### Step 6: model analysis and validation

# %% [markdown]
# #### histogram of rf models selected for each voxel
# models with large indices are small rfs. so looks like we need higher resolution.

# %%
_=plt.hist(frf,ms.receptive_fields.G)
plt.xlabel('smaller-->bigger')

# %% [markdown]
# #### sum of all selected rfs.

# %%
plt.imshow(np.sum(ms.receptive_fields.make_rf_stack(64, min_pix_per_radius=1)[frf,:,:], axis=0), cmap='hot')

# %% [markdown]
# #### prediction accuracy for all voxels

# %%
##grab validation data
val_voxel_data = voxel_data[valIdx,0:nvox]

# %%
from hrf_fitting.src.feature_weighted_rf_models import bigmult

# %%
##generate predictions one voxel at a time
# pred = prediction_menu(val_mst, ffw[np.newaxis,:,:], rf_indices = frf)


##generate predictions one voxel at a time
pred = np.zeros((Tval,nvox))
for v in range(nvox-1):  ##<<some kind of bug in training function, last voxel getting skipped.
    pred[:,v] = np.squeeze(bigmult(val_mst[np.newaxis,frf[v],:,:],
                                   ffw[np.newaxis,:,v, np.newaxis]))

# %%
##get correlation = prediction accuracy
val_cc = []  
for v in range(nvox-1): 
    cc = pearsonr(val_voxel_data[:,v],pred[:,v])
    if not np.isnan(cc[0]):
        val_cc.append(cc[0])

# %%
##histogram of prediction accuracy, all voxels
_=plt.hist(val_cc,100)
plt.yscale('log')
plt.ylim([10**0, 10**3])
plt.xlim([-.4, 0.8])
# Out:
# (-0.4, 0.8)

# %%
np.sum(map(lambda x: x > 0.25, val_cc))
# Out:
# 2401

# %%
np.sum(map(lambda x,y: x > y, beh[-1,:], fvl))
# Out:
# 1158
