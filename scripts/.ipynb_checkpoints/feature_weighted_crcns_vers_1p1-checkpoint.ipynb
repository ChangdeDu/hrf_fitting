# %% [markdown]
# ## Use feature-weighted rf model on the crcns vim-1 dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py
from time import time
from glob import glob
from scipy.io import loadmat
from PIL import Image
from scipy.stats import pearsonr
from hrf_fitting.src.feature_weighted_rf_models import make_rf_table,receptive_fields, model_space, prediction_menu, bigmult
from hrf_fitting.src.feature_weighted_rf_models import train_fwrf_model
from hrf_fitting.src.gabor_feature_dictionaries import gabor_feature_maps

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN X

# %% [markdown]
# ### Step 0: Load crcns stimuli

# %% [markdown]
# #### load crcns stimuli

# %%
##known stimulus parameters
Ttrn = 1750
Tval = 120
S = 500
T = Ttrn+Tval
train_stim_files = glob('/media/tnaselar/Data/crcns_datasets/vim-1/Stimuli_Trn_FullRes*.mat')
val_stim_file = '/media/tnaselar/Data/crcns_datasets/vim-1/Stimuli_Val_FullRes.mat'
n_image_channels = 1 ##could be 3 for color images.

# %%
##allocate memory for stim
training_stim = np.zeros((Ttrn,S,S),dtype='float32')

##load training stim
cnt = 0
for sl in sorted(train_stim_files):
    this_h5 = h5py.File(sl,'r')
    this_train_stim = this_h5['stimTrn']
    this_num_stim = this_train_stim.shape[-1]
    training_stim[cnt:cnt+this_num_stim,:,:] = np.transpose(this_train_stim[:],[2,1,0])
    cnt += this_num_stim
    this_h5.close()
    
##load validation stim
val_h5 = h5py.File(val_stim_file,'r')
validation_stim = np.transpose(val_h5['stimVal'][:],[2,1,0])
val_h5.close()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.imshow(validation_stim[0,:,:],cmap='gray')
plt.subplot(1,2,2)
plt.imshow(training_stim[-1,:,:],cmap = 'gray')

# %% [markdown]
# ### Step 1: construct feature maps

# %%
n_orientations = 8
deg_per_stimulus = 20
lowest_sp_freq = .25 ##cyc/deg
highest_sp_freq = 6.25
num_sp_freq = 8
pix_per_cycle = 4#2.13333333
complex_cell = True

print 'D = total number of features = %d' %(n_orientations * num_sp_freq)
# Out:
# D = total number of features = 64

# %% [markdown]
# #### construct gabor wavelet stack

# %%
gfm = gabor_feature_maps(n_orientations,
                         deg_per_stimulus,
                         (lowest_sp_freq,highest_sp_freq,num_sp_freq),
                         pix_per_cycle=pix_per_cycle,complex_cell=complex_cell,
                         diams_per_filter = 4,
                        cycles_per_radius = 2.0)

# %%
gfm.gbr_table.head(9)
# Out:
#    cycles per deg.  cycles_per_filter  filter size (deg.)  pix per stimulus  \
# 0         0.250000                 16           64.000000         20.000000
# 1         0.395955                 16           40.408642         31.676392
# 2         0.627121                 16           25.513412         50.169691
# 3         0.993247                 16           16.108787         79.459740
# 4         1.573124                 16           10.170847        125.849895
# 5         2.491544                 16            6.421720        199.323532
# 6         3.946156                 16            4.054578        315.692518
# 7         6.250000                 16            2.560000        500.000000
# 8         0.250000                 16           64.000000         20.000000
#
#    pix_per_filter  radius of Gauss. envelope (deg)  orientation
# 0              64                         8.000000     0.000000
# 1              64                         5.051080     0.000000
# 2              64                         3.189177     0.000000
# 3              64                         2.013598     0.000000
# 4              64                         1.271356     0.000000
# 5              64                         0.802715     0.000000
# 6              64                         0.506822     0.000000
# 7              64                         0.320000     0.000000
# 8              64                         8.000000     0.392699

# %%
gfm.filter_stack.shape
# Out:
# (64, 1, 64, 64)

# %% [markdown]
# #### see one of the gabors

# %%
o =  8##choose an orientation
plt.imshow(np.imag(gfm.filter_stack[o,0,:,:]),cmap='gray')

# %% [markdown]
# ### Step 2: receptive fields

# %%
deg_per_radius = (.5, 8, 8) ##rf sizes in degrees (smallest, largest, number of sizes)
spacing = 1. ##spacing between rf's in degrees
rf = receptive_fields(deg_per_stimulus,deg_per_radius,spacing)

# %%
rf.rf_table.head()
# Out:
#    deg_per_radius      x_deg  y_deg
# 0             0.5 -10.000000    -10
# 1             0.5  -8.947368    -10
# 2             0.5  -7.894737    -10
# 3             0.5  -6.842105    -10
# 4             0.5  -5.789474    -10

# %%
print 'G = number of rf models = %d' %(rf.rf_table.shape[0])
# Out:
# G = number of rf models = 3200

# %% [markdown]
# ### Step 3: Model space

# %% [markdown]
# #### instantiate model space object

# %%
##construct the model space
init_feat_dict = gfm.create_feature_maps(training_stim[0,np.newaxis,np.newaxis,:,:])
ms = model_space(init_feat_dict, rf)
# Out:
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.002947 s.
# feature 1 took 0.002363 s.
# feature 2 took 0.003206 s.
# feature 3 took 0.005336 s.
# feature 4 took 0.009251 s.
# feature 5 took 0.021313 s.
# feature 6 took 0.055833 s.
# feature 7 took 0.322627 s.
# feature 8 took 0.002049 s.
# feature 9 took 0.002359 s.
# feature 10 took 0.003209 s.
# feature 11 took 0.005669 s.
# feature 12 took 0.009399 s.
# feature 13 took 0.019630 s.
# feature 14 took 0.053533 s.
# feature 15 took 0.295563 s.
# feature 16 took 0.002151 s.
# feature 17 took 0.002355 s.
# feature 18 took 0.003224 s.
# feature 19 took 0.005420 s.
# feature 20 took 0.009480 s.
# feature 21 took 0.019680 s.
# feature 22 took 0.053814 s.
# feature 23 took 0.289539 s.
# feature 24 took 0.002065 s.
# feature 25 took 0.002375 s.
# feature 26 took 0.003131 s.
# feature 27 took 0.005420 s.
# feature 28 took 0.009431 s.
# feature 29 took 0.019782 s.
# feature 30 took 0.053834 s.
# feature 31 took 0.287274 s.
# feature 32 took 0.002031 s.
# feature 33 took 0.002381 s.
# feature 34 took 0.003099 s.
# feature 35 took 0.005623 s.
# feature 36 took 0.009343 s.
# feature 37 took 0.019799 s.
# feature 38 took 0.053694 s.
# feature 39 took 0.288154 s.
# feature 40 took 0.002038 s.
# feature 41 took 0.002391 s.
# feature 42 took 0.003163 s.
# feature 43 took 0.005369 s.
# feature 44 took 0.009458 s.
# feature 45 took 0.019691 s.
# feature 46 took 0.054060 s.
# feature 47 took 0.294580 s.
# feature 48 took 0.002171 s.
# feature 49 took 0.002456 s.
# feature 50 took 0.003143 s.
# feature 51 took 0.005589 s.
# feature 52 took 0.009453 s.
# feature 53 took 0.019745 s.
# feature 54 took 0.054325 s.
# feature 55 took 0.303922 s.
# feature 56 took 0.002044 s.
# feature 57 took 0.002354 s.
# feature 58 took 0.003164 s.
# feature 59 took 0.005557 s.
# feature 60 took 0.009395 s.
# feature 61 took 0.019512 s.
# feature 62 took 0.053990 s.
# feature 63 took 0.295319 s.

# %% [markdown]
# #### construct training/validation model space tensors

# %%
##loop over training stimuli because feature maps for all training stim. > 48Gb
training_mst = np.zeros((ms.receptive_fields.G, Ttrn, ms.D)).astype('float32')

num_chunks = 2
stim_dx = np.linspace(0,T-1,num=num_chunks+1, endpoint=True,dtype='int')

cnt = 0
for t in stim_dx[1:]:
    this_training_feature_dict = gfm.create_feature_maps(training_stim[cnt:cnt+t,np.newaxis,:,:])
    training_mst[:,cnt:cnt+t,:] = ms.construct_model_space_tensor(this_training_feature_dict,normalize=False)
    cnt += t

##clear up memory
this_training_feature_dict = []

##normalize and save normalization constants
training_mst = ms.normalize_model_space_tensor(training_mst, save=True)


##should work in one shot for because not too big
val_feature_dict = gfm.create_feature_maps(validation_stim[:,np.newaxis,:,:])
# Out:
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.523943 s.
# feature 1 took 0.924431 s.
# feature 2 took 2.000299 s.
# feature 3 took 3.628052 s.
# feature 4 took 6.933353 s.
# feature 5 took 16.702323 s.
# feature 6 took 47.087329 s.
# feature 7 took 364.513938 s.
# feature 8 took 0.522578 s.
# feature 9 took 0.929673 s.
# feature 10 took 2.005903 s.
# feature 11 took 3.631060 s.
# feature 12 took 6.933523 s.
# feature 13 took 16.192662 s.
# feature 14 took 47.355927 s.
# feature 15 took 364.331628 s.
# feature 16 took 0.520829 s.
# feature 17 took 0.929826 s.
# feature 18 took 2.006477 s.
# feature 19 took 3.632639 s.
# feature 20 took 6.933426 s.
# feature 21 took 16.196834 s.
# feature 22 took 47.360176 s.
# feature 23 took 364.675068 s.
# feature 24 took 0.520461 s.
# feature 25 took 0.929366 s.
# feature 26 took 2.005629 s.
# feature 27 took 3.632041 s.
# feature 28 took 6.934563 s.
# feature 29 took 16.194085 s.
# feature 30 took 47.379004 s.
# feature 31 took 364.342423 s.
# feature 32 took 0.520762 s.
# feature 33 took 0.929764 s.
# feature 34 took 2.005953 s.
# feature 35 took 3.631832 s.
# feature 36 took 6.934600 s.
# feature 37 took 16.193901 s.
# feature 38 took 47.354341 s.
# feature 39 took 364.568111 s.
# feature 40 took 0.521077 s.
# feature 41 took 0.929927 s.
# feature 42 took 2.006375 s.
# feature 43 took 3.631789 s.
# feature 44 took 6.933033 s.
# feature 45 took 16.192687 s.
# feature 46 took 47.360817 s.
# feature 47 took 364.498936 s.
# feature 48 took 0.520388 s.
# feature 49 took 0.932417 s.
# feature 50 took 2.005305 s.
# feature 51 took 3.631560 s.
# feature 52 took 6.934946 s.
# feature 53 took 16.192259 s.
# feature 54 took 47.351073 s.
# feature 55 took 364.504348 s.
# feature 56 took 0.520373 s.
# feature 57 took 0.931816 s.
# feature 58 took 2.005540 s.
# feature 59 took 3.632370 s.
# feature 60 took 6.934441 s.
# feature 61 took 16.191419 s.
# feature 62 took 47.356378 s.
# feature 63 took 364.594656 s.
# -----------feature: 0
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 1
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 2
# -----------feature: 3
# -----------feature: 4
# -----------feature: 5
# -----------feature: 6
# -----------feature: 7
# -----------feature: 8
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 9
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 10
# -----------feature: 11
# -----------feature: 12
# -----------feature: 13
# -----------feature: 14
# -----------feature: 15
# -----------feature: 16
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 17
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 18
# -----------feature: 19
# -----------feature: 20
# -----------feature: 21
# -----------feature: 22
# -----------feature: 23
# -----------feature: 24
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 25
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 26
# -----------feature: 27
# -----------feature: 28
# -----------feature: 29
# -----------feature: 30
# -----------feature: 31
# -----------feature: 32
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 33
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 34
# -----------feature: 35
# -----------feature: 36
# -----------feature: 37
# -----------feature: 38
# -----------feature: 39
# -----------feature: 40
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 41
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 42
# -----------feature: 43
# -----------feature: 44
# -----------feature: 45
# -----------feature: 46
# -----------feature: 47
# -----------feature: 48
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 49
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 50
# -----------feature: 51
# -----------feature: 52
# -----------feature: 53
# -----------feature: 54
# -----------feature: 55
# -----------feature: 56
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 57
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 58
# -----------feature: 59
# -----------feature: 60
# -----------feature: 61
# -----------feature: 62
# -----------feature: 63
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.450970 s.
# feature 1 took 0.812457 s.
# feature 2 took 1.751361 s.
# feature 3 took 3.182894 s.
# feature 4 took 6.071873 s.
# feature 5 took 14.108710 s.
# feature 6 took 41.036691 s.
# feature 7 took 295.237390 s.
# feature 8 took 0.453889 s.
# feature 9 took 0.814224 s.
# feature 10 took 1.755362 s.
# feature 11 took 3.187475 s.
# feature 12 took 6.078033 s.
# feature 13 took 14.132597 s.
# feature 14 took 41.067668 s.
# feature 15 took 296.176242 s.
# feature 16 took 0.454585 s.
# feature 17 took 0.813565 s.
# feature 18 took 1.755477 s.
# feature 19 took 3.187168 s.
# feature 20 took 6.076856 s.
# feature 21 took 14.132997 s.
# feature 22 took 41.023077 s.
# feature 23 took 296.245205 s.
# feature 24 took 0.453995 s.
# feature 25 took 0.814266 s.
# feature 26 took 1.755905 s.
# feature 27 took 3.187995 s.
# feature 28 took 6.077727 s.
# feature 29 took 14.129601 s.
# feature 30 took 41.050295 s.
# feature 31 took 296.495973 s.
# feature 32 took 0.459555 s.
# feature 33 took 0.818151 s.
# feature 34 took 1.763264 s.
# feature 35 took 3.190108 s.
# feature 36 took 6.081404 s.
# feature 37 took 14.131635 s.
# feature 38 took 41.101468 s.
# feature 39 took 299.293845 s.
# feature 40 took 0.459791 s.
# feature 41 took 0.818576 s.
# feature 42 took 1.762884 s.
# feature 43 took 3.192844 s.
# feature 44 took 6.081141 s.
# feature 45 took 14.178756 s.
# feature 46 took 41.329306 s.
# feature 47 took 299.443365 s.
# feature 48 took 0.455672 s.
# feature 49 took 0.815488 s.
# feature 50 took 1.759923 s.
# feature 51 took 3.186893 s.
# feature 52 took 6.077606 s.
# feature 53 took 14.171370 s.
# feature 54 took 41.304810 s.
# feature 55 took 299.030259 s.
# feature 56 took 0.456552 s.
# feature 57 took 0.814953 s.
# feature 58 took 1.759688 s.
# feature 59 took 3.188032 s.
# feature 60 took 6.080385 s.
# feature 61 took 14.169687 s.
# feature 62 took 41.312008 s.
# feature 63 took 299.464234 s.
# -----------feature: 0
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 1
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 2
# -----------feature: 3
# -----------feature: 4
# -----------feature: 5
# -----------feature: 6
# -----------feature: 7
# -----------feature: 8
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 9
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 10
# -----------feature: 11
# -----------feature: 12
# -----------feature: 13
# -----------feature: 14
# -----------feature: 15
# -----------feature: 16
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 17
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 18
# -----------feature: 19
# -----------feature: 20
# -----------feature: 21
# -----------feature: 22
# -----------feature: 23
# -----------feature: 24
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 25
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 26
# -----------feature: 27
# -----------feature: 28
# -----------feature: 29
# -----------feature: 30
# -----------feature: 31
# -----------feature: 32
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 33
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 34
# -----------feature: 35
# -----------feature: 36
# -----------feature: 37
# -----------feature: 38
# -----------feature: 39
# -----------feature: 40
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 41
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 42
# -----------feature: 43
# -----------feature: 44
# -----------feature: 45
# -----------feature: 46
# -----------feature: 47
# -----------feature: 48
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 49
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 50
# -----------feature: 51
# -----------feature: 52
# -----------feature: 53
# -----------feature: 54
# -----------feature: 55
# -----------feature: 56
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 57
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 58
# -----------feature: 59
# -----------feature: 60
# -----------feature: 61
# -----------feature: 62
# -----------feature: 63
# normalization constants have been saved
# model_space_tensor has been z-scored
# allocating memory for feature maps
# constructing feature maps
# feature 0 took 0.670958 s.
# feature 1 took 0.727724 s.
# feature 2 took 0.861982 s.
# feature 3 took 1.075404 s.
# feature 4 took 1.501479 s.
# feature 5 took 2.683549 s.
# feature 6 took 6.614410 s.
# feature 7 took 44.198845 s.
# feature 8 took 0.670746 s.
# feature 9 took 0.728484 s.
# feature 10 took 0.862977 s.
# feature 11 took 1.074241 s.
# feature 12 took 1.498601 s.
# feature 13 took 2.690492 s.
# feature 14 took 6.664744 s.
# feature 15 took 44.310080 s.
# feature 16 took 0.671079 s.
# feature 17 took 0.724838 s.
# feature 18 took 0.863882 s.
# feature 19 took 1.074482 s.
# feature 20 took 1.506945 s.
# feature 21 took 2.690827 s.
# feature 22 took 6.654035 s.
# feature 23 took 44.437183 s.
# feature 24 took 0.670303 s.
# feature 25 took 0.725342 s.
# feature 26 took 0.865020 s.
# feature 27 took 1.075747 s.
# feature 28 took 1.504693 s.
# feature 29 took 2.692724 s.
# feature 30 took 6.667541 s.
# feature 31 took 44.748122 s.
# feature 32 took 0.683141 s.
# feature 33 took 0.739059 s.
# feature 34 took 0.874489 s.
# feature 35 took 1.085439 s.
# feature 36 took 1.512907 s.
# feature 37 took 2.706056 s.
# feature 38 took 6.663003 s.
# feature 39 took 44.329034 s.
# feature 40 took 0.671433 s.
# feature 41 took 0.730304 s.
# feature 42 took 0.863686 s.
# feature 43 took 1.075313 s.
# feature 44 took 1.504617 s.
# feature 45 took 2.694949 s.
# feature 46 took 6.667975 s.
# feature 47 took 44.765833 s.
# feature 48 took 0.671570 s.
# feature 49 took 0.729187 s.
# feature 50 took 0.863248 s.
# feature 51 took 1.076126 s.
# feature 52 took 1.502646 s.
# feature 53 took 2.694846 s.
# feature 54 took 6.657139 s.
# feature 55 took 44.333407 s.
# feature 56 took 0.671649 s.
# feature 57 took 0.728651 s.
# feature 58 took 0.863928 s.
# feature 59 took 1.076588 s.
# feature 60 took 1.503629 s.
# feature 61 took 2.695673 s.
# feature 62 took 6.652588 s.
# feature 63 took 44.564740 s.

# %%
validation_mst = ms.construct_model_space_tensor(val_feature_dict,normalize=True)
# Out:
# -----------feature: 0
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 1
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 2
# -----------feature: 3
# -----------feature: 4
# -----------feature: 5
# -----------feature: 6
# -----------feature: 7
# -----------feature: 8
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 9
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 10
# -----------feature: 11
# -----------feature: 12
# -----------feature: 13
# -----------feature: 14
# -----------feature: 15
# -----------feature: 16
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 17
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 18
# -----------feature: 19
# -----------feature: 20
# -----------feature: 21
# -----------feature: 22
# -----------feature: 23
# -----------feature: 24
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 25
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 26
# -----------feature: 27
# -----------feature: 28
# -----------feature: 29
# -----------feature: 30
# -----------feature: 31
# -----------feature: 32
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 33
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 34
# -----------feature: 35
# -----------feature: 36
# -----------feature: 37
# -----------feature: 38
# -----------feature: 39
# -----------feature: 40
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 41
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 42
# -----------feature: 43
# -----------feature: 44
# -----------feature: 45
# -----------feature: 46
# -----------feature: 47
# -----------feature: 48
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 49
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 50
# -----------feature: 51
# -----------feature: 52
# -----------feature: 53
# -----------feature: 54
# -----------feature: 55
# -----------feature: 56
# at pixel resolution 20 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 57
# at pixel resolution 32 the following rfs will default to 0: (array([ 0.5]),)
# -----------feature: 58
# -----------feature: 59
# -----------feature: 60
# -----------feature: 61
# -----------feature: 62
# -----------feature: 63
# model_space_tensor has been z-scored

# %% [markdown]
# ### Step 4: load and package crcns voxel data

# %%
voxel_file = '/media/tnaselar/Data/crcns_datasets/vim-1/EstimatedResponses.mat'
crcns_voxel_data = h5py.File(voxel_file,'r')
crcns_voxel_data.keys()
# Out:
# [u'dataTrnS1',
#  u'dataTrnS2',
#  u'dataValS1',
#  u'dataValS2',
#  u'roiS1',
#  u'roiS2',
#  u'voxIdxS1',
#  u'voxIdxS2']

# %% [markdown]
# #### remove nans, becuase this data-set has some. otherwise even one nan will infect gradient for every voxel.

# %%
voxel_data = np.concatenate((crcns_voxel_data['dataValS1'],crcns_voxel_data['dataTrnS1']),axis=0).astype('float32')

# %%
plt.plot(voxel_data[:,-1])

# %%
no_nan = np.isnan(voxel_data).sum(axis=0) == 0 ##<<pull voxels with nans 
voxel_data = voxel_data[:,no_nan]
print voxel_data.shape
V = voxel_data.shape[1]
# Out:
# (1870, 22701)

# %%
crcns_voxel_data.close()

# %% [markdown]
# #### get training/validation views on voxel_data

# %%
nvox=V
trnIdx = np.arange(Tval,T)
valIdx = np.arange(0,Tval)
trn_voxel_data = voxel_data[trnIdx,0:nvox]
val_voxel_data = voxel_data[valIdx,0:nvox]

# %% [markdown]
# ### Step 5: run that shit.

# %% [markdown]
# #### train the model!

# %%
fvl,ffw,frf,beh = train_fwrf_model(training_mst,
                 trn_voxel_data,
                 initial_feature_weights='zeros',
                 voxel_binsize = nvox,
                 rf_grid_binsize=10,
                 learning_rate=10**(-5.),
                 max_iters = 200,
                 early_stop_fraction=0.2,
                 report_every = 25)
# Out:
# --------------voxels from 0 to 22701
# --------candiate rf models 0 to 10
# -------
# errors: 349.967780
# change in best rf: 103853.000000
# norm of feature weights: 3.074836
# improvements: 227010
# 0.432818889618
# -------
# errors: 348.862685
# change in best rf: -50.000000
# norm of feature weights: 35.615162
# improvements: 32087
# 9.16684699059
# -------
# errors: 349.116292
# change in best rf: 43.000000
# norm of feature weights: 56.775677
# improvements: 14891
# 8.93861508369
# -------
# errors: 349.541259
# change in best rf: -7.000000
# norm of feature weights: 72.727066
# improvements: 8496
# 8.79469609261
# -------
# errors: 349.986996
# change in best rf: 1.000000
# norm of feature weights: 85.267471
# improvements: 5593
# 8.7135682106
# -------
# errors: 350.407683
# change in best rf: 10.000000
# norm of feature weights: 95.376526
# improvements: 3996
# 8.67588305473
# -------
# errors: 350.787841
# change in best rf: -21.000000
# norm of feature weights: 103.677307
# improvements: 3097
# 8.64020609856
# -------
# errors: 351.124381
# change in best rf: 38.000000
# norm of feature weights: 110.592415
# improvements: 2525
# 8.61822414398
# --------candiate rf models 10 to 20
# -------
# errors: 350.014168
# change in best rf: 98653.000000
# norm of feature weights: 3.011086
# improvements: 227010
# 0.424718141556
# -------
# errors: 348.963865
# change in best rf: -61.000000
# norm of feature weights: 35.094887
# improvements: 32908
# 9.20967197418
# -------
# errors: 349.174991
# change in best rf: 56.000000
# norm of feature weights: 56.289848
# improvements: 15805
# 8.95544886589
# -------
# errors: 349.571201
# change in best rf: 42.000000
# norm of feature weights: 72.330818
# improvements: 8934
# 8.81650781631
# -------
# errors: 350.000218
# change in best rf: 24.000000
# norm of feature weights: 84.958366
# improvements: 5747
# 8.73175907135
# -------
# errors: 350.409487
# change in best rf: 39.000000
# norm of feature weights: 95.141724
# improvements: 4134
# 8.67860984802
# -------
# errors: 350.780734
# change in best rf: -4.000000
# norm of feature weights: 103.502556
# improvements: 3222
# 8.64866685867
# -------
# errors: 351.109821
# change in best rf: 17.000000
# norm of feature weights: 110.464920
# improvements: 2651
# 8.62438797951
# --------candiate rf models 20 to 30
# -------
# errors: 349.931487
# change in best rf: 105217.000000
# norm of feature weights: 3.093603
# improvements: 227010
# 0.424915075302
# -------
# errors: 348.780992
# change in best rf: 78.000000
# norm of feature weights: 35.527889
# improvements: 33182
# 9.21155619621
# -------
# errors: 349.027527
# change in best rf: -19.000000
# norm of feature weights: 56.588005
# improvements: 15353
# 8.94580197334
# -------
# errors: 349.449571
# change in best rf: -13.000000
# norm of feature weights: 72.463303
# improvements: 8743
# 8.80737996101
# -------
# errors: 349.894404
# change in best rf: -4.000000
# norm of feature weights: 84.956558
# improvements: 5691
# 8.72593021393
# -------
# errors: 350.312346
# change in best rf: -37.000000
# norm of feature weights: 95.046158
# improvements: 4132
# 8.67822289467
# -------
# errors: 350.688737
# change in best rf: 34.000000
# norm of feature weights: 103.352371
# improvements: 3210
# 8.6406481266
# -------
# errors: 351.021139
# change in best rf: -35.000000
# norm of feature weights: 110.294144
# improvements: 2654
# 8.62138009071
# --------candiate rf models 30 to 40
# -------
# errors: 349.995110
# change in best rf: 96349.000000
# norm of feature weights: 3.031180
# improvements: 227010
# 0.423550844193
# -------
# errors: 348.963998
# change in best rf: -11.000000
# norm of feature weights: 35.149185
# improvements: 32237
# 9.19968104362
# -------
# errors: 349.197497
# change in best rf: -86.000000
# norm of feature weights: 56.306423
# improvements: 15355
# 8.94237303734
# -------
# errors: 349.603976
# change in best rf: -22.000000
# norm of feature weights: 72.311363
# improvements: 8772
# 8.79824304581
# -------
# errors: 350.039656
# change in best rf: -31.000000
# norm of feature weights: 84.911072
# improvements: 5642
# 8.71229195595
# -------
# errors: 350.451300
# change in best rf: 24.000000
# norm of feature weights: 95.076561
# improvements: 4057
# 8.65970301628
# -------
# errors: 350.822500
# change in best rf: -17.000000
# norm of feature weights: 103.430763
# improvements: 3164
# 8.63570809364
# -------
# errors: 351.150213
# change in best rf: 17.000000
# norm of feature weights: 110.397324
# improvements: 2597
# 8.61619305611
# --------candiate rf models 40 to 50
# -------
# errors: 349.887381
# change in best rf: 106604.000000
# norm of feature weights: 3.112576
# improvements: 227010
# 0.42519402504
# -------
# errors: 348.706452
# change in best rf: 19.000000
# norm of feature weights: 35.650135
# improvements: 32752
# 9.23708105087
# -------
# errors: 348.973345
# change in best rf: 11.000000
# norm of feature weights: 56.649033
# improvements: 15102
# 8.96408295631
# -------
# errors: 349.412060
# change in best rf: 9.000000
# norm of feature weights: 72.429886
# improvements: 8547
# 8.82451605797
# -------
# errors: 349.866626
# change in best rf: 14.000000
# norm of feature weights: 84.832436
# improvements: 5600
# 8.74066591263
# -------
# errors: 350.289552
# change in best rf: 5.000000
# norm of feature weights: 94.842003
# improvements: 4089
# 8.69177794456
# -------
# errors: 350.668331
# change in best rf: 13.000000
# norm of feature weights: 103.080269
# improvements: 3202
# 8.65991806984
# -------
# errors: 351.002037
# change in best rf: 10.000000
# norm of feature weights: 109.965805
# improvements: 2671
# 8.64393687248
# --------candiate rf models 50 to 60
# -------
# errors: 349.954912
# change in best rf: 93334.000000
# norm of feature weights: 3.051785
# improvements: 227010
# 0.424850940704
# -------
# errors: 348.933964
# change in best rf: -50.000000
# norm of feature weights: 35.443779
# improvements: 31941
# 9.20441198349
# -------
# errors: 349.194288
# change in best rf: 23.000000
# norm of feature weights: 56.600899
# improvements: 14919
# 8.95201301575
# -------
# errors: 349.625561
# change in best rf: -48.000000
# norm of feature weights: 72.551659
# improvements: 8448
# 8.80934095383
# -------
# errors: 350.078200
# change in best rf: 8.000000
# norm of feature weights: 85.078278
# improvements: 5448
# 8.72470998764
# -------
# errors: 350.501537
# change in best rf: 20.000000
# norm of feature weights: 95.164833
# improvements: 3899
# 8.67553806305
# -------
# errors: 350.878648
# change in best rf: 16.000000
# norm of feature weights: 103.442390
# improvements: 3040
# 8.64631581306
# -------
# errors: 351.208386
# change in best rf: -3.000000
# norm of feature weights: 110.339111
# improvements: 2493
# 8.62392997742
# --------candiate rf models 60 to 70
# -------
# errors: 349.842265
# change in best rf: 106765.000000
# norm of feature weights: 3.163230
# improvements: 227010
# 0.423700809479
# -------
# errors: 348.647601
# change in best rf: 16.000000
# norm of feature weights: 36.001408
# improvements: 32479
# 9.22283005714
# -------
# errors: 348.929992
# change in best rf: -26.000000
# norm of feature weights: 57.073624
# improvements: 14605
# 8.95360803604
# -------
# errors: 349.383611
# change in best rf: 88.000000
# norm of feature weights: 72.814293
# improvements: 8281
# 8.80865502357
# -------
# errors: 349.848027
# change in best rf: -21.000000
# norm of feature weights: 85.128769
# improvements: 5404
# 8.72494292259
# -------
# errors: 350.274896
# change in best rf: -23.000000
# norm of feature weights: 95.027527
# improvements: 3965
# 8.67700481415
# -------
# errors: 350.652209
# change in best rf: 19.000000
# norm of feature weights: 103.145615
# improvements: 3145
# 8.64649295807
# -------
# errors: 350.979673
# change in best rf: -6.000000
# norm of feature weights: 109.908943
# improvements: 2644
# 8.62668323517
# --------candiate rf models 70 to 80
# -------
# errors: 349.910370
# change in best rf: 91587.000000
# norm of feature weights: 3.052176
# improvements: 227010
# 0.423856019974
# -------
# errors: 348.847395
# change in best rf: -131.000000
# norm of feature weights: 35.584423
# improvements: 31863
# 9.19905400276
# -------
# errors: 349.115464
# change in best rf: -17.000000
# norm of feature weights: 56.620827
# improvements: 14450
# 8.93534088135
# -------
# errors: 349.556935
# change in best rf: 3.000000
# norm of feature weights: 72.399315
# improvements: 8072
# 8.79003691673
# -------
# errors: 350.012574
# change in best rf: -4.000000
# norm of feature weights: 84.755486
# improvements: 5337
# 8.70731091499
# -------
# errors: 350.432691
# change in best rf: 30.000000
# norm of feature weights: 94.689545
# improvements: 3921
# 8.66259503365
# -------
# errors: 350.804368
# change in best rf: 1.000000
# norm of feature weights: 102.838646
# improvements: 3119
# 8.63613700867
# -------
# errors: 351.127416
# change in best rf: 21.000000
# norm of feature weights: 109.631821
# improvements: 2629
# 8.61369395256
# --------candiate rf models 80 to 90
# -------
# errors: 349.805467
# change in best rf: 108614.000000
# norm of feature weights: 3.236774
# improvements: 227010
# 0.423799991608
# -------
# errors: 348.590750
# change in best rf: -57.000000
# norm of feature weights: 36.348614
# improvements: 32605
# 9.21413207054
# -------
# errors: 348.893196
# change in best rf: -59.000000
# norm of feature weights: 57.523006
# improvements: 14252
# 8.93639302254
# -------
# errors: 349.362915
# change in best rf: 43.000000
# norm of feature weights: 73.281487
# improvements: 7804
# 8.78673696518
# -------
# errors: 349.839527
# change in best rf: -30.000000
# norm of feature weights: 85.558403
# improvements: 5001
# 8.70348596573
# -------
# errors: 350.274998
# change in best rf: 7.000000
# norm of feature weights: 95.386650
# improvements: 3598
# 8.6567568779
# -------
# errors: 350.657347
# change in best rf: 3.000000
# norm of feature weights: 103.417023
# improvements: 2864
# 8.63450980186
# -------
# errors: 350.986518
# change in best rf: 16.000000
# norm of feature weights: 110.085831
# improvements: 2407
# 8.61334991455
# --------candiate rf models 90 to 100
# -------
# errors: 349.881480
# change in best rf: 92771.000000
# norm of feature weights: 3.069238
# improvements: 227010
# 0.424247026443
# -------
# errors: 348.784830
# change in best rf: 51.000000
# norm of feature weights: 35.827068
# improvements: 31687
# 9.19930100441
# -------
# errors: 349.062402
# change in best rf: 43.000000
# norm of feature weights: 56.908466
# improvements: 14446
# 8.93846988678
# -------
# errors: 349.507099
# change in best rf: -12.000000
# norm of feature weights: 72.676865
# improvements: 8122
# 8.79115819931
# -------
# errors: 349.962461
# change in best rf: 46.000000
# norm of feature weights: 84.995491
# improvements: 5341
# 8.71265506744
# -------
# errors: 350.379964
# change in best rf: -15.000000
# norm of feature weights: 94.878548
# improvements: 3925
# 8.6637160778
# -------
# errors: 350.747083
# change in best rf: 4.000000
# norm of feature weights: 102.971352
# improvements: 3078
# 8.64409804344
# -------
# errors: 351.064925
# change in best rf: -9.000000
# norm of feature weights: 109.708008
# improvements: 2623
# 8.61899280548
# --------candiate rf models 100 to 110
# -------
# errors: 349.792314
# change in best rf: 110976.000000
# norm of feature weights: 3.306391
# improvements: 227010
# 0.423364877701
# -------
# errors: 348.506290
# change in best rf: -8.000000
# norm of feature weights: 36.712597
# improvements: 31410
# 9.20468091965
# -------
# errors: 348.821788
# change in best rf: -6.000000
# norm of feature weights: 57.976402
# improvements: 13279
# 8.92444205284
# -------
# errors: 349.307444
# change in best rf: -51.000000
# norm of feature weights: 73.738693
# improvements: 7212
# 8.77066206932
# -------
# errors: 349.796911
# change in best rf: 24.000000
# norm of feature weights: 85.961174
# improvements: 4553
# 8.68975305557
# -------
# errors: 350.240657
# change in best rf: -9.000000
# norm of feature weights: 95.697594
# improvements: 3284
# 8.64887595177
# -------
# errors: 350.627692
# change in best rf: 17.000000
# norm of feature weights: 103.614174
# improvements: 2589
# 8.62076401711
# -------
# errors: 350.959046
# change in best rf: -24.000000
# norm of feature weights: 110.157768
# improvements: 2199
# 8.60328888893
# --------candiate rf models 110 to 120
# -------
# errors: 349.863183
# change in best rf: 93580.000000
# norm of feature weights: 3.109384
# improvements: 227010
# 0.424357891083
# -------
# errors: 348.756883
# change in best rf: 110.000000
# norm of feature weights: 36.163090
# improvements: 29289
# 9.1845510006
# -------
# errors: 349.105850
# change in best rf: -15.000000
# norm of feature weights: 57.269779
# improvements: 12995
# 8.91479110718
# -------
# errors: 349.610208
# change in best rf: 19.000000
# norm of feature weights: 72.946083
# improvements: 7127
# 8.77253913879
# -------
# errors: 350.110337
# change in best rf: -16.000000
# norm of feature weights: 85.113747
# improvements: 4615
# 8.69149112701
# -------
# errors: 350.558701
# change in best rf: 25.000000
# norm of feature weights: 94.817902
# improvements: 3337
# 8.64841294289
# -------
# errors: 350.945473
# change in best rf: 12.000000
# norm of feature weights: 102.721443
# improvements: 2605
# 8.62042713165
# -------
# errors: 351.275235
# change in best rf: -7.000000
# norm of feature weights: 109.268410
# improvements: 2230
# 8.61124396324
# --------candiate rf models 120 to 130
# -------
# errors: 349.782518
# change in best rf: 112940.000000
# norm of feature weights: 3.385566
# improvements: 227010
# 0.424474954605
# -------
# errors: 348.496995
# change in best rf: -56.000000
# norm of feature weights: 37.016117
# improvements: 30425
# 9.20310497284
# -------
# errors: 348.827913
# change in best rf: -25.000000
# norm of feature weights: 58.357273
# improvements: 13009
# 8.91772794724
# -------
# errors: 349.326404
# change in best rf: -58.000000
# norm of feature weights: 74.081146
# improvements: 7209
# 8.77321004868
# -------
# errors: 349.824753
# change in best rf: -4.000000
# norm of feature weights: 86.192833
# improvements: 4588
# 8.69261598587
# -------
# errors: 350.273297
# change in best rf: -51.000000
# norm of feature weights: 95.780685
# improvements: 3340
# 8.64827394485
# -------
# errors: 350.661388
# change in best rf: -10.000000
# norm of feature weights: 103.531601
# improvements: 2653
# 8.62733101845
# -------
# errors: 350.992572
# change in best rf: -27.000000
# norm of feature weights: 109.904144
# improvements: 2246
# 8.6100320816
# --------candiate rf models 130 to 140
# -------
# errors: 349.838948
# change in best rf: 93061.000000
# norm of feature weights: 3.165736
# improvements: 227010
# 0.424147129059
# -------
# errors: 348.671060
# change in best rf: -8.000000
# norm of feature weights: 36.703194
# improvements: 29383
# 9.18375110626
# -------
# errors: 349.010009
# change in best rf: 54.000000
# norm of feature weights: 57.859398
# improvements: 13260
# 8.92205905914
# -------
# errors: 349.507441
# change in best rf: -57.000000
# norm of feature weights: 73.466881
# improvements: 7489
# 8.77791810036
# -------
# errors: 349.999471
# change in best rf: 39.000000
# norm of feature weights: 85.516785
# improvements: 4897
# 8.69991517067
# -------
# errors: 350.438913
# change in best rf: 39.000000
# norm of feature weights: 95.082954
# improvements: 3622
# 8.66183209419
# -------
# errors: 350.817372
# change in best rf: 1.000000
# norm of feature weights: 102.841881
# improvements: 2935
# 8.63279604912
# -------
# errors: 351.138878
# change in best rf: -11.000000
# norm of feature weights: 109.244156
# improvements: 2517
# 8.61390686035
# --------candiate rf models 140 to 150
# -------
# errors: 349.786667
# change in best rf: 112703.000000
# norm of feature weights: 3.423493
# improvements: 227010
# 0.426898956299
# -------
# errors: 348.563875
# change in best rf: -230.000000
# norm of feature weights: 37.297112
# improvements: 28646
# 9.19354701042
# -------
# errors: 348.953719
# change in best rf: -180.000000
# norm of feature weights: 58.679619
# improvements: 12019
# 8.90243697166
# -------
# errors: 349.498034
# change in best rf: -47.000000
# norm of feature weights: 74.306160
# improvements: 6494
# 8.76250100136
# -------
# errors: 350.025837
# change in best rf: -51.000000
# norm of feature weights: 86.246819
# improvements: 4164
# 8.68480491638
# -------
# errors: 350.492301
# change in best rf: -7.000000
# norm of feature weights: 95.632446
# improvements: 3067
# 8.64120197296
# -------
# errors: 350.889865
# change in best rf: -30.000000
# norm of feature weights: 103.174782
# improvements: 2466
# 8.62375807762
# -------
# errors: 351.224190
# change in best rf: 4.000000
# norm of feature weights: 109.345741
# improvements: 2132
# 8.60682988167
# --------candiate rf models 150 to 160
# -------
# errors: 349.787087
# change in best rf: 93499.000000
# norm of feature weights: 3.279736
# improvements: 227010
# 0.423830032349
# -------
# errors: 348.546464
# change in best rf: -12.000000
# norm of feature weights: 37.213825
# improvements: 28736
# 9.18236494064
# -------
# errors: 348.901405
# change in best rf: 55.000000
# norm of feature weights: 58.440998
# improvements: 12800
# 8.9092400074
# -------
# errors: 349.413144
# change in best rf: 75.000000
# norm of feature weights: 73.966232
# improvements: 7094
# 8.76529288292
# -------
# errors: 349.916687
# change in best rf: -18.000000
# norm of feature weights: 85.863487
# improvements: 4726
# 8.69465684891
# -------
# errors: 350.364982
# change in best rf: -29.000000
# norm of feature weights: 95.248932
# improvements: 3434
# 8.6536090374
# -------
# errors: 350.749713
# change in best rf: -25.000000
# norm of feature weights: 102.821495
# improvements: 2732
# 8.62210512161
# -------
# errors: 351.076311
# change in best rf: 0.000000
# norm of feature weights: 109.043037
# improvements: 2370
# 8.61012005806
# --------candiate rf models 160 to 170
# -------
# errors: 349.764041
# change in best rf: 111776.000000
# norm of feature weights: 3.420986
# improvements: 227010
# 0.423416137695
# -------
# errors: 348.491324
# change in best rf: -225.000000
# norm of feature weights: 37.627071
# improvements: 29356
# 9.18935203552
# -------
# errors: 348.877096
# change in best rf: -88.000000
# norm of feature weights: 59.039581
# improvements: 12582
# 8.90445303917
# -------
# errors: 349.418530
# change in best rf: -19.000000
# norm of feature weights: 74.632027
# improvements: 6821
# 8.76187300682
# -------
# errors: 349.942910
# change in best rf: -60.000000
# norm of feature weights: 86.503235
# improvements: 4332
# 8.67861914635
# -------
# errors: 350.402785
# change in best rf: -15.000000
# norm of feature weights: 95.798325
# improvements: 3168
# 8.6382920742
# -------
# errors: 350.790750
# change in best rf: 36.000000
# norm of feature weights: 103.238525
# improvements: 2585
# 8.62095189095
# -------
# errors: 351.115352
# change in best rf: 17.000000
# norm of feature weights: 109.301880
# improvements: 2181
# 8.60420608521
# --------candiate rf models 170 to 180
# -------
# errors: 349.720429
# change in best rf: 93098.000000
# norm of feature weights: 3.403939
# improvements: 227010
# 0.424249887466
# -------
# errors: 348.444335
# change in best rf: 191.000000
# norm of feature weights: 37.591717
# improvements: 27265
# 9.17301988602
# -------
# errors: 348.850607
# change in best rf: 80.000000
# norm of feature weights: 58.785999
# improvements: 11695
# 8.8907148838
# -------
# errors: 349.397845
# change in best rf: 36.000000
# norm of feature weights: 74.192635
# improvements: 6468
# 8.75566601753
# -------
# errors: 349.921970
# change in best rf: -20.000000
# norm of feature weights: 85.922676
# improvements: 4237
# 8.68216991425
# -------
# errors: 350.381067
# change in best rf: -10.000000
# norm of feature weights: 95.115356
# improvements: 3111
# 8.6368060112
# -------
# errors: 350.769729
# change in best rf: 24.000000
# norm of feature weights: 102.483894
# improvements: 2506
# 8.61926388741
# -------
# errors: 351.095848
# change in best rf: -17.000000
# norm of feature weights: 108.499298
# improvements: 2114
# 8.60411119461
# --------candiate rf models 180 to 190
# -------
# errors: 349.740856
# change in best rf: 108480.000000
# norm of feature weights: 3.431129
# improvements: 227010
# 0.423553943634
# -------
# errors: 348.391337
# change in best rf: -138.000000
# norm of feature weights: 38.180317
# improvements: 29743
# 9.19499897957
# -------
# errors: 348.757707
# change in best rf: -7.000000
# norm of feature weights: 59.710732
# improvements: 12696
# 8.91174697876
# -------
# errors: 349.284520
# change in best rf: -102.000000
# norm of feature weights: 75.286896
# improvements: 6954
# 8.76402997971
# -------
# errors: 349.793601
# change in best rf: -13.000000
# norm of feature weights: 87.059113
# improvements: 4510
# 8.68699002266
# -------
# errors: 350.237235
# change in best rf: -25.000000
# norm of feature weights: 96.205589
# improvements: 3301
# 8.64675283432
# -------
# errors: 350.610682
# change in best rf: 17.000000
# norm of feature weights: 103.469147
# improvements: 2683
# 8.61852383614
# -------
# errors: 350.919973
# change in best rf: -21.000000
# norm of feature weights: 109.341743
# improvements: 2341
# 8.61131978035
# --------candiate rf models 190 to 200
# -------
# errors: 349.679443
# change in best rf: 91446.000000
# norm of feature weights: 3.478106
# improvements: 227010
# 0.426289081573
# -------
# errors: 348.353614
# change in best rf: 115.000000
# norm of feature weights: 37.972500
# improvements: 27561
# 9.17747092247
# -------
# errors: 348.749930
# change in best rf: -42.000000
# norm of feature weights: 59.230087
# improvements: 11902
# 8.89304685593
# -------
# errors: 349.285132
# change in best rf: 47.000000
# norm of feature weights: 74.665459
# improvements: 6602
# 8.75457501411
# -------
# errors: 349.793475
# change in best rf: -4.000000
# norm of feature weights: 86.391113
# improvements: 4349
# 8.68065214157
# -------
# errors: 350.235035
# change in best rf: -33.000000
# norm of feature weights: 95.553963
# improvements: 3218
# 8.64322805405
# -------
# errors: 350.604652
# change in best rf: 8.000000
# norm of feature weights: 102.873764
# improvements: 2653
# 8.62476015091
# -------
# errors: 350.910982
# change in best rf: 6.000000
# norm of feature weights: 108.826363
# improvements: 2311
# 8.60696697235
# --------candiate rf models 200 to 210
# -------
# errors: 349.743555
# change in best rf: 106844.000000
# norm of feature weights: 3.404820
# improvements: 227010
# 0.424101114273
# -------
# errors: 348.358923
# change in best rf: -162.000000
# norm of feature weights: 38.286304
# improvements: 27662
# 9.1773378849
# -------
# errors: 348.774458
# change in best rf: 16.000000
# norm of feature weights: 59.815723
# improvements: 11140
# 8.88980197906
# -------
# errors: 349.356338
# change in best rf: 56.000000
# norm of feature weights: 75.371078
# improvements: 5951
# 8.74366807938
# -------
# errors: 349.911924
# change in best rf: 60.000000
# norm of feature weights: 87.107544
# improvements: 3813
# 8.6734380722
# -------
# errors: 350.393766
# change in best rf: 38.000000
# norm of feature weights: 96.207344
# improvements: 2755
# 8.63133907318
# -------
# errors: 350.796566
# change in best rf: 18.000000
# norm of feature weights: 103.416588
# improvements: 2189
# 8.61075401306
# -------
# errors: 351.128913
# change in best rf: 47.000000
# norm of feature weights: 109.230072
# improvements: 1889
# 8.59880304337
# --------candiate rf models 210 to 220
# -------
# errors: 349.719984
# change in best rf: 92510.000000
# norm of feature weights: 3.414009
# improvements: 227010
# 0.424073934555
# -------
# errors: 348.325417
# change in best rf: 86.000000
# norm of feature weights: 38.330612
# improvements: 27031
# 9.17976284027
# -------
# errors: 348.746526
# change in best rf: -38.000000
# norm of feature weights: 59.873657
# improvements: 10909
# 8.88138079643
# -------
# errors: 349.318027
# change in best rf: 75.000000
# norm of feature weights: 75.492706
# improvements: 5700
# 8.73664307594
# -------
# errors: 349.861233
# change in best rf: -6.000000
# norm of feature weights: 87.314743
# improvements: 3676
# 8.66562414169
# -------
# errors: 350.329743
# change in best rf: -11.000000
# norm of feature weights: 96.508476
# improvements: 2754
# 8.6248550415
# -------
# errors: 350.719857
# change in best rf: -4.000000
# norm of feature weights: 103.813118
# improvements: 2255
# 8.60501003265
# -------
# errors: 351.041604
# change in best rf: 22.000000
# norm of feature weights: 109.719078
# improvements: 1943
# 8.59699583054
# --------candiate rf models 220 to 230
# -------
# errors: 349.780022
# change in best rf: 105898.000000
# norm of feature weights: 3.326219
# improvements: 227010
# 0.424872875214
# -------
# errors: 348.278402
# change in best rf: -55.000000
# norm of feature weights: 38.170437
# improvements: 28651
# 9.1962249279
# -------
# errors: 348.649422
# change in best rf: 31.000000
# norm of feature weights: 59.695435
# improvements: 11545
# 8.90086698532
# -------
# errors: 349.204245
# change in best rf: 21.000000
# norm of feature weights: 75.238365
# improvements: 6042
# 8.74871206284
# -------
# errors: 349.744261
# change in best rf: 9.000000
# norm of feature weights: 86.972862
# improvements: 3785
# 8.67216897011
# -------
# errors: 350.216031
# change in best rf: 7.000000
# norm of feature weights: 96.085388
# improvements: 2734
# 8.63150906563
# -------
# errors: 350.613408
# change in best rf: 7.000000
# norm of feature weights: 103.319687
# improvements: 2220
# 8.60960888863
# -------
# errors: 350.943083
# change in best rf: 33.000000
# norm of feature weights: 109.166809
# improvements: 1948
# 8.60302710533
# --------candiate rf models 230 to 240
# -------
# errors: 349.783184
# change in best rf: 92129.000000
# norm of feature weights: 3.298310
# improvements: 227010
# 0.424701929092
# -------
# errors: 348.378208
# change in best rf: 88.000000
# norm of feature weights: 38.122807
# improvements: 26672
# 9.1816649437
# -------
# errors: 348.846024
# change in best rf: 1.000000
# norm of feature weights: 59.643291
# improvements: 10394
# 8.88186502457
# -------
# errors: 349.455359
# change in best rf: 36.000000
# norm of feature weights: 75.247177
# improvements: 5361
# 8.72715783119
# -------
# errors: 350.030981
# change in best rf: 19.000000
# norm of feature weights: 87.065636
# improvements: 3374
# 8.6579349041
# -------
# errors: 350.527310
# change in best rf: -2.000000
# norm of feature weights: 96.266914
# improvements: 2443
# 8.62328100204
# -------
# errors: 350.942564
# change in best rf: -39.000000
# norm of feature weights: 103.589165
# improvements: 1985
# 8.60004019737
# -------
# errors: 351.285794
# change in best rf: 23.000000
# norm of feature weights: 109.521797
# improvements: 1708
# 8.59327793121
# --------candiate rf models 240 to 250
# -------
# errors: 349.840855
# change in best rf: 104775.000000
# norm of feature weights: 3.239173
# improvements: 227010
# 0.424187898636
# -------
# errors: 348.364476
# change in best rf: 35.000000
# norm of feature weights: 38.044201
# improvements: 29488
# 9.20122218132
# -------
# errors: 348.725088
# change in best rf: -64.000000
# norm of feature weights: 59.592930
# improvements: 11854
# 8.90413594246
# -------
# errors: 349.271426
# change in best rf: -17.000000
# norm of feature weights: 75.124474
# improvements: 6239
# 8.75296902657
# -------
# errors: 349.802042
# change in best rf: 7.000000
# norm of feature weights: 86.843208
# improvements: 3911
# 8.67554306984
# -------
# errors: 350.267669
# change in best rf: -66.000000
# norm of feature weights: 95.946152
# improvements: 2886
# 8.63620781898
# -------
# errors: 350.660693
# change in best rf: -19.000000
# norm of feature weights: 103.178734
# improvements: 2347
# 8.61835289001
# -------
# errors: 350.988200
# change in best rf: -12.000000
# norm of feature weights: 109.031296
# improvements: 2042
# 8.60037994385
# --------candiate rf models 250 to 260
# -------
# errors: 349.856248
# change in best rf: 93469.000000
# norm of feature weights: 3.213837
# improvements: 227010
# 0.424618005753
# -------
# errors: 348.484918
# change in best rf: -75.000000
# norm of feature weights: 37.898788
# improvements: 26485
# 9.17863512039
# -------
# errors: 348.943862
# change in best rf: -15.000000
# norm of feature weights: 59.354103
# improvements: 10550
# 8.87913799286
# -------
# errors: 349.548514
# change in best rf: -11.000000
# norm of feature weights: 74.921089
# improvements: 5502
# 8.7286028862
# -------
# errors: 350.121696
# change in best rf: 16.000000
# norm of feature weights: 86.721306
# improvements: 3439
# 8.65731978416
# -------
# errors: 350.619239
# change in best rf: 2.000000
# norm of feature weights: 95.916504
# improvements: 2516
# 8.62340784073
# -------
# errors: 351.036893
# change in best rf: -37.000000
# norm of feature weights: 103.240143
# improvements: 2031
# 8.60763502121
# -------
# errors: 351.382860
# change in best rf: -20.000000
# norm of feature weights: 109.178802
# improvements: 1748
# 8.59270215034
# --------candiate rf models 260 to 270
# -------
# errors: 349.884848
# change in best rf: 107527.000000
# norm of feature weights: 3.167419
# improvements: 227010
# 0.424731016159
# -------
# errors: 348.417030
# change in best rf: -144.000000
# norm of feature weights: 38.032238
# improvements: 31520
# 9.22715377808
# -------
# errors: 348.719477
# change in best rf: -49.000000
# norm of feature weights: 59.537491
# improvements: 12902
# 8.92531299591
# -------
# errors: 349.211125
# change in best rf: -19.000000
# norm of feature weights: 75.004845
# improvements: 6935
# 8.77950382233
# -------
# errors: 349.695507
# change in best rf: 8.000000
# norm of feature weights: 86.665344
# improvements: 4415
# 8.69338989258
# -------
# errors: 350.121509
# change in best rf: 9.000000
# norm of feature weights: 95.722176
# improvements: 3333
# 8.64532399178
# -------
# errors: 350.480606
# change in best rf: 5.000000
# norm of feature weights: 102.920998
# improvements: 2695
# 8.62657999992
# -------
# errors: 350.779321
# change in best rf: 16.000000
# norm of feature weights: 108.750717
# improvements: 2380
# 8.61510515213
# --------candiate rf models 270 to 280
# -------
# errors: 349.905341
# change in best rf: 91992.000000
# norm of feature weights: 3.143521
# improvements: 227010
# 0.425095081329
# -------
# errors: 348.586398
# change in best rf: -25.000000
# norm of feature weights: 37.979294
# improvements: 26212
# 9.18039083481
# -------
# errors: 349.026557
# change in best rf: -39.000000
# norm of feature weights: 59.528687
# improvements: 10801
# 8.88232684135
# -------
# errors: 349.615443
# change in best rf: -4.000000
# norm of feature weights: 75.160194
# improvements: 5711
# 8.735683918
# -------
# errors: 350.173378
# change in best rf: 5.000000
# norm of feature weights: 87.004326
# improvements: 3731
# 8.66985487938
# -------
# errors: 350.655211
# change in best rf: -16.000000
# norm of feature weights: 96.227203
# improvements: 2767
# 8.63250494003
# -------
# errors: 351.058002
# change in best rf: -30.000000
# norm of feature weights: 103.565315
# improvements: 2235
# 8.60667705536
# -------
# errors: 351.390284
# change in best rf: 11.000000
# norm of feature weights: 109.507767
# improvements: 1926
# 8.59442782402
# --------candiate rf models 280 to 290
# -------
# errors: 349.937928
# change in best rf: 108342.000000
# norm of feature weights: 3.073597
# improvements: 227010
# 0.423609018326
# -------
# errors: 348.563161
# change in best rf: -122.000000
# norm of feature weights: 37.817677
# improvements: 30913
# 9.21711397171
# -------
# errors: 348.883743
# change in best rf: 24.000000
# norm of feature weights: 59.341019
# improvements: 12777
# 8.91629314423
# -------
# errors: 349.382176
# change in best rf: -40.000000
# norm of feature weights: 74.894020
# improvements: 6916
# 8.76413202286
# -------
# errors: 349.869102
# change in best rf: -10.000000
# norm of feature weights: 86.672607
# improvements: 4402
# 8.68247294426
# -------
# errors: 350.295830
# change in best rf: -14.000000
# norm of feature weights: 95.860924
# improvements: 3226
# 8.64565491676
# -------
# errors: 350.655546
# change in best rf: 0.000000
# norm of feature weights: 103.194389
# improvements: 2635
# 8.62905716896
# -------
# errors: 350.954751
# change in best rf: 2.000000
# norm of feature weights: 109.156181
# improvements: 2281
# 8.60559010506
# --------candiate rf models 290 to 300
# -------
# errors: 349.958554
# change in best rf: 92115.000000
# norm of feature weights: 3.060746
# improvements: 227010
# 0.424767971039
# -------
# errors: 348.653664
# change in best rf: -58.000000
# norm of feature weights: 37.782547
# improvements: 26958
# 9.17749404907
# -------
# errors: 349.072843
# change in best rf: -81.000000
# norm of feature weights: 59.310661
# improvements: 10950
# 8.88122105598
# -------
# errors: 349.652789
# change in best rf: -35.000000
# norm of feature weights: 74.919693
# improvements: 5760
# 8.73593997955
# -------
# errors: 350.206450
# change in best rf: -57.000000
# norm of feature weights: 86.752533
# improvements: 3677
# 8.66108703613
# -------
# errors: 350.685313
# change in best rf: 7.000000
# norm of feature weights: 95.977745
# improvements: 2727
# 8.62319302559
# -------
# errors: 351.085123
# change in best rf: -1.000000
# norm of feature weights: 103.329384
# improvements: 2192
# 8.61135005951
# -------
# errors: 351.415510
# change in best rf: 3.000000
# norm of feature weights: 109.293793
# improvements: 1894
# 8.59369087219
# --------candiate rf models 300 to 310
# -------
# errors: 350.013979
# change in best rf: 105816.000000
# norm of feature weights: 3.007600
# improvements: 227010
# 0.426098823547
# -------
# errors: 348.692512
# change in best rf: -23.000000
# norm of feature weights: 37.710274
# improvements: 32138
# 9.21735596657
# -------
# errors: 349.013671
# change in best rf: -61.000000
# norm of feature weights: 59.526596
# improvements: 13163
# 8.9249958992
# -------
# errors: 349.527713
# change in best rf: 4.000000
# norm of feature weights: 75.359184
# improvements: 6884
# 8.7709569931
# -------
# errors: 350.038045
# change in best rf: 36.000000
# norm of feature weights: 87.371849
# improvements: 4258
# 8.69137096405
# -------
# errors: 350.490563
# change in best rf: -4.000000
# norm of feature weights: 96.744049
# improvements: 3079
# 8.64125800133
# -------
# errors: 350.875416
# change in best rf: -22.000000
# norm of feature weights: 104.214653
# improvements: 2495
# 8.61710190773
# -------
# errors: 351.197892
# change in best rf: -6.000000
# norm of feature weights: 110.273132
# improvements: 2162
# 8.61050581932
# --------candiate rf models 310 to 321
# -------
# errors: 349.941169
# change in best rf: 123038.000000
# norm of feature weights: 3.134907
# improvements: 249711
# 0.461097002029
# -------
# errors: 348.418422
# change in best rf: -125.000000
# norm of feature weights: 39.365467
# improvements: 31113
# 10.0084400177
# -------
# errors: 348.715475
# change in best rf: -46.000000
# norm of feature weights: 62.170212
# improvements: 12713
# 9.70079302788
# -------
# errors: 349.232597
# change in best rf: 6.000000
# norm of feature weights: 78.741249
# improvements: 6604
# 9.53427410126
# -------
# errors: 349.755124
# change in best rf: -56.000000
# norm of feature weights: 91.310089
# improvements: 4116
# 9.44642496109
# -------
# errors: 350.221040
# change in best rf: -18.000000
# norm of feature weights: 101.103607
# improvements: 3009
# 9.40539884567
# -------
# errors: 350.618655
# change in best rf: -43.000000
# norm of feature weights: 108.895065
# improvements: 2384
# 9.38104295731
# -------
# errors: 350.952844
# change in best rf: -47.000000
# norm of feature weights: 115.199043
# improvements: 1998
# 9.36942315102
# --------candiate rf models 321 to 331
# -------
# errors: 350.044950
# change in best rf: 102222.000000
# norm of feature weights: 2.979784
# improvements: 227010
# 0.425262212753
# -------
# errors: 348.752532
# change in best rf: -35.000000
# norm of feature weights: 37.401073
# improvements: 32076
# 9.21640300751
# -------
# errors: 349.054157
# change in best rf: 101.000000
# norm of feature weights: 59.220276
# improvements: 13525
# 8.93026304245
# -------
# errors: 349.548001
# change in best rf: 57.000000
# norm of feature weights: 75.130363
# improvements: 7182
# 8.77481007576
# -------
# errors: 350.044363
# change in best rf: 27.000000
# norm of feature weights: 87.254784
# improvements: 4541
# 8.6938970089
# -------
# errors: 350.489937
# change in best rf: -17.000000
# norm of feature weights: 96.751396
# improvements: 3248
# 8.64711904526
# -------
# errors: 350.872199
# change in best rf: 22.000000
# norm of feature weights: 104.347145
# improvements: 2607
# 8.63015508652
# -------
# errors: 351.193512
# change in best rf: -11.000000
# norm of feature weights: 110.525574
# improvements: 2200
# 8.61274909973
# --------candiate rf models 331 to 341
# -------
# errors: 350.014373
# change in best rf: 113240.000000
# norm of feature weights: 2.903753
# improvements: 227010
# 0.424201011658
# -------
# errors: 348.628433
# change in best rf: 46.000000
# norm of feature weights: 37.373802
# improvements: 29876
# 9.18838310242
# -------
# errors: 348.954445
# change in best rf: -87.000000
# norm of feature weights: 59.250042
# improvements: 12520
# 8.91103696823
# -------
# errors: 349.489328
# change in best rf: -1.000000
# norm of feature weights: 75.187851
# improvements: 6460
# 8.75988507271
# -------
# errors: 350.028361
# change in best rf: -10.000000
# norm of feature weights: 87.286713
# improvements: 3990
# 8.67683315277
# -------
# errors: 350.511191
# change in best rf: -55.000000
# norm of feature weights: 96.710686
# improvements: 2830
# 8.62965393066
# -------
# errors: 350.924753
# change in best rf: -11.000000
# norm of feature weights: 104.196724
# improvements: 2214
# 8.60406684875
# -------
# errors: 351.272499
# change in best rf: -8.000000
# norm of feature weights: 110.238029
# improvements: 1910
# 8.59552788734
# --------candiate rf models 341 to 351
# -------
# errors: 350.075997
# change in best rf: 101241.000000
# norm of feature weights: 2.906149
# improvements: 227010
# 0.424382925034
# -------
# errors: 348.885698
# change in best rf: -5.000000
# norm of feature weights: 37.105549
# improvements: 30016
# 9.20351314545
# -------
# errors: 349.228233
# change in best rf: -40.000000
# norm of feature weights: 58.894547
# improvements: 12851
# 8.90951704979
# -------
# errors: 349.745188
# change in best rf: -18.000000
# norm of feature weights: 74.810356
# improvements: 6878
# 8.75206804276
# -------
# errors: 350.257069
# change in best rf: -12.000000
# norm of feature weights: 86.943680
# improvements: 4365
# 8.67286705971
# -------
# errors: 350.710967
# change in best rf: 10.000000
# norm of feature weights: 96.443222
# improvements: 3140
# 8.63471198082
# -------
# errors: 351.097832
# change in best rf: 6.000000
# norm of feature weights: 104.032593
# improvements: 2489
# 8.61255908012
# -------
# errors: 351.422918
# change in best rf: -6.000000
# norm of feature weights: 110.194839
# improvements: 2103
# 8.59652900696
# --------candiate rf models 351 to 361
# -------
# errors: 350.035571
# change in best rf: 114820.000000
# norm of feature weights: 2.832216
# improvements: 227010
# 0.424615859985
# -------
# errors: 348.676966
# change in best rf: -209.000000
# norm of feature weights: 37.231678
# improvements: 29878
# 9.18259000778
# -------
# errors: 349.002043
# change in best rf: 4.000000
# norm of feature weights: 59.120827
# improvements: 12463
# 8.90292596817
# -------
# errors: 349.537851
# change in best rf: -8.000000
# norm of feature weights: 75.116959
# improvements: 6253
# 8.75055718422
# -------
# errors: 350.080111
# change in best rf: -17.000000
# norm of feature weights: 87.286621
# improvements: 3812
# 8.67339491844
# -------
# errors: 350.569205
# change in best rf: 6.000000
# norm of feature weights: 96.781960
# improvements: 2702
# 8.6332218647
# -------
# errors: 350.990860
# change in best rf: 5.000000
# norm of feature weights: 104.334480
# improvements: 2094
# 8.6122469902
# -------
# errors: 351.347008
# change in best rf: -4.000000
# norm of feature weights: 110.435043
# improvements: 1747
# 8.59458613396
# --------candiate rf models 361 to 371
# -------
# errors: 350.099082
# change in best rf: 99718.000000
# norm of feature weights: 2.844214
# improvements: 227010
# 0.42356300354
# -------
# errors: 348.951259
# change in best rf: -100.000000
# norm of feature weights: 37.029163
# improvements: 28923
# 9.18538022041
# -------
# errors: 349.323940
# change in best rf: -23.000000
# norm of feature weights: 58.933083
# improvements: 12233
# 8.90447092056
# -------
# errors: 349.868964
# change in best rf: -27.000000
# norm of feature weights: 74.958496
# improvements: 6567
# 8.75844788551
# -------
# errors: 350.406210
# change in best rf: 32.000000
# norm of feature weights: 87.178879
# improvements: 4103
# 8.67654585838
# -------
# errors: 350.884636
# change in best rf: 16.000000
# norm of feature weights: 96.741600
# improvements: 2977
# 8.63841080666
# -------
# errors: 351.295010
# change in best rf: 28.000000
# norm of feature weights: 104.370415
# improvements: 2360
# 8.61717391014
# -------
# errors: 351.640739
# change in best rf: -7.000000
# norm of feature weights: 110.550285
# improvements: 1991
# 8.60028195381
# --------candiate rf models 371 to 381
# -------
# errors: 350.045809
# change in best rf: 115523.000000
# norm of feature weights: 2.779268
# improvements: 227010
# 0.424882888794
# -------
# errors: 348.672358
# change in best rf: 50.000000
# norm of feature weights: 36.960857
# improvements: 30108
# 9.19599699974
# -------
# errors: 348.965231
# change in best rf: 35.000000
# norm of feature weights: 58.830761
# improvements: 12741
# 8.91807413101
# -------
# errors: 349.475760
# change in best rf: 21.000000
# norm of feature weights: 74.882362
# improvements: 6630
# 8.76578593254
# -------
# errors: 350.001274
# change in best rf: 7.000000
# norm of feature weights: 87.141045
# improvements: 4056
# 8.68164587021
# -------
# errors: 350.479777
# change in best rf: 54.000000
# norm of feature weights: 96.743179
# improvements: 2883
# 8.63693499565
# -------
# errors: 350.896793
# change in best rf: 5.000000
# norm of feature weights: 104.409882
# improvements: 2226
# 8.61485099792
# -------
# errors: 351.252263
# change in best rf: 22.000000
# norm of feature weights: 110.625679
# improvements: 1824
# 8.60218811035
# --------candiate rf models 381 to 391
# -------
# errors: 350.110285
# change in best rf: 97943.000000
# norm of feature weights: 2.805968
# improvements: 227010
# 0.424432992935
# -------
# errors: 348.910719
# change in best rf: -8.000000
# norm of feature weights: 37.227760
# improvements: 28995
# 9.19601297379
# -------
# errors: 349.277453
# change in best rf: 31.000000
# norm of feature weights: 59.251728
# improvements: 12165
# 8.91942381859
# -------
# errors: 349.827163
# change in best rf: 64.000000
# norm of feature weights: 75.305908
# improvements: 6559
# 8.76572394371
# -------
# errors: 350.372620
# change in best rf: 6.000000
# norm of feature weights: 87.496071
# improvements: 4045
# 8.69243407249
# -------
# errors: 350.859966
# change in best rf: -12.000000
# norm of feature weights: 96.989594
# improvements: 2912
# 8.64674401283
# -------
# errors: 351.277831
# change in best rf: -6.000000
# norm of feature weights: 104.522087
# improvements: 2252
# 8.61711597443
# -------
# errors: 351.629651
# change in best rf: -12.000000
# norm of feature weights: 110.586220
# improvements: 1888
# 8.60216617584
# --------candiate rf models 391 to 401
# -------
# errors: 349.775598
# change in best rf: 125052.000000
# norm of feature weights: 2.852167
# improvements: 227010
# 0.424067974091
# -------
# errors: 348.387983
# change in best rf: -117.000000
# norm of feature weights: 37.549225
# improvements: 28803
# 9.18927383423
# -------
# errors: 348.770325
# change in best rf: -85.000000
# norm of feature weights: 59.699810
# improvements: 11826
# 8.9059779644
# -------
# errors: 349.358761
# change in best rf: 45.000000
# norm of feature weights: 75.885040
# improvements: 6024
# 8.75363206863
# -------
# errors: 349.945870
# change in best rf: -25.000000
# norm of feature weights: 88.212257
# improvements: 3671
# 8.6699590683
# -------
# errors: 350.471575
# change in best rf: 23.000000
# norm of feature weights: 97.856079
# improvements: 2569
# 8.6293861866
# -------
# errors: 350.924517
# change in best rf: -40.000000
# norm of feature weights: 105.554604
# improvements: 2008
# 8.60919213295
# -------
# errors: 351.307695
# change in best rf: -3.000000
# norm of feature weights: 111.800453
# improvements: 1705
# 8.60219597816
# --------candiate rf models 401 to 411
# -------
# errors: 349.900629
# change in best rf: 102156.000000
# norm of feature weights: 3.703835
# improvements: 227010
# 0.424540042877
# -------
# errors: 349.751777
# change in best rf: 177.000000
# norm of feature weights: 40.319584
# improvements: 27878
# 9.20854902267
# -------
# errors: 350.762760
# change in best rf: 32.000000
# norm of feature weights: 63.645168
# improvements: 10683
# 8.89224982262
# -------
# errors: 351.761800
# change in best rf: 55.000000
# norm of feature weights: 80.724419
# improvements: 5414
# 8.73780894279
# -------
# errors: 352.619294
# change in best rf: 25.000000
# norm of feature weights: 93.948982
# improvements: 3370
# 8.66310214996
# -------
# errors: 353.328290
# change in best rf: -5.000000
# norm of feature weights: 104.610764
# improvements: 2420
# 8.62367391586
# -------
# errors: 353.912327
# change in best rf: -10.000000
# norm of feature weights: 113.480156
# improvements: 1936
# 8.61070799828
# -------
# errors: 354.396627
# change in best rf: -1.000000
# norm of feature weights: 121.043320
# improvements: 1666
# 8.59551501274
# --------candiate rf models 411 to 421
# -------
# errors: 349.791288
# change in best rf: 127476.000000
# norm of feature weights: 3.613944
# improvements: 227010
# 0.425776958466
# -------
# errors: 349.390962
# change in best rf: -92.000000
# norm of feature weights: 40.386642
# improvements: 26056
# 9.17570185661
# -------
# errors: 350.281322
# change in best rf: -84.000000
# norm of feature weights: 63.870632
# improvements: 10122
# 8.8743622303
# -------
# errors: 351.205160
# change in best rf: -64.000000
# norm of feature weights: 81.118500
# improvements: 5074
# 8.72319698334
# -------
# errors: 352.014262
# change in best rf: -67.000000
# norm of feature weights: 94.494858
# improvements: 3208
# 8.65380001068
# -------
# errors: 352.691549
# change in best rf: -54.000000
# norm of feature weights: 105.282509
# improvements: 2336
# 8.62486386299
# -------
# errors: 353.254028
# change in best rf: -21.000000
# norm of feature weights: 114.250298
# improvements: 1877
# 8.60499095917
# -------
# errors: 353.723339
# change in best rf: 9.000000
# norm of feature weights: 121.884804
# improvements: 1612
# 8.59307193756
# --------candiate rf models 421 to 431
# -------
# errors: 349.860243
# change in best rf: 102312.000000
# norm of feature weights: 3.742217
# improvements: 227010
# 0.423785924911
# -------
# errors: 349.706689
# change in best rf: 55.000000
# norm of feature weights: 40.220161
# improvements: 27729
# 9.21289396286
# -------
# errors: 350.717548
# change in best rf: -31.000000
# norm of feature weights: 63.400154
# improvements: 10510
# 8.90027093887
# -------
# errors: 351.714933
# change in best rf: 59.000000
# norm of feature weights: 80.357193
# improvements: 5248
# 8.73592305183
# -------
# errors: 352.568477
# change in best rf: 36.000000
# norm of feature weights: 93.485344
# improvements: 3300
# 8.65937304497
# -------
# errors: 353.273333
# change in best rf: 48.000000
# norm of feature weights: 104.077408
# improvements: 2382
# 8.62686896324
# -------
# errors: 353.852501
# change in best rf: 1.000000
# norm of feature weights: 112.902527
# improvements: 1904
# 8.60738301277
# -------
# errors: 354.332051
# change in best rf: -20.000000
# norm of feature weights: 120.443993
# improvements: 1653
# 8.59494996071
# --------candiate rf models 431 to 441
# -------
# errors: 349.749637
# change in best rf: 126784.000000
# norm of feature weights: 3.635666
# improvements: 227010
# 0.424221038818
# -------
# errors: 349.343510
# change in best rf: -181.000000
# norm of feature weights: 40.308697
# improvements: 26418
# 9.18077421188
# -------
# errors: 350.223672
# change in best rf: 147.000000
# norm of feature weights: 63.675266
# improvements: 10317
# 8.87808799744
# -------
# errors: 351.139097
# change in best rf: -82.000000
# norm of feature weights: 80.819061
# improvements: 5318
# 8.73092722893
# -------
# errors: 351.938957
# change in best rf: -15.000000
# norm of feature weights: 94.107872
# improvements: 3353
# 8.6589949131
# -------
# errors: 352.605096
# change in best rf: 6.000000
# norm of feature weights: 104.828773
# improvements: 2472
# 8.62690806389
# -------
# errors: 353.155569
# change in best rf: -18.000000
# norm of feature weights: 113.752419
# improvements: 2024
# 8.61321496964
# -------
# errors: 353.613064
# change in best rf: 0.000000
# norm of feature weights: 121.364792
# improvements: 1752
# 8.5994989872
# --------candiate rf models 441 to 451
# -------
# errors: 349.811441
# change in best rf: 103574.000000
# norm of feature weights: 3.795532
# improvements: 227010
# 0.423819065094
# -------
# errors: 349.655377
# change in best rf: 82.000000
# norm of feature weights: 40.206814
# improvements: 27383
# 9.20416593552
# -------
# errors: 350.670602
# change in best rf: 51.000000
# norm of feature weights: 63.272026
# improvements: 10212
# 8.88090896606
# -------
# errors: 351.670692
# change in best rf: 35.000000
# norm of feature weights: 80.120064
# improvements: 5093
# 8.72385311127
# -------
# errors: 352.523904
# change in best rf: -4.000000
# norm of feature weights: 93.155441
# improvements: 3145
# 8.6543982029
# -------
# errors: 353.225961
# change in best rf: 3.000000
# norm of feature weights: 103.675659
# improvements: 2324
# 8.62079691887
# -------
# errors: 353.801696
# change in best rf: -2.000000
# norm of feature weights: 112.450455
# improvements: 1891
# 8.60282993317
# -------
# errors: 354.276821
# change in best rf: -20.000000
# norm of feature weights: 119.961227
# improvements: 1647
# 8.59291887283
# --------candiate rf models 451 to 461
# -------
# errors: 349.704118
# change in best rf: 126029.000000
# norm of feature weights: 3.660637
# improvements: 227010
# 0.424426078796
# -------
# errors: 349.293843
# change in best rf: -9.000000
# norm of feature weights: 40.250156
# improvements: 26632
# 9.16560602188
# -------
# errors: 350.174565
# change in best rf: -94.000000
# norm of feature weights: 63.489201
# improvements: 10398
# 8.85275292397
# -------
# errors: 351.085167
# change in best rf: -110.000000
# norm of feature weights: 80.510124
# improvements: 5409
# 8.69601798058
# -------
# errors: 351.878096
# change in best rf: -31.000000
# norm of feature weights: 93.687691
# improvements: 3503
# 8.63248205185
# -------
# errors: 352.535516
# change in best rf: -58.000000
# norm of feature weights: 104.315887
# improvements: 2617
# 8.61843705177
# -------
# errors: 353.075457
# change in best rf: 4.000000
# norm of feature weights: 113.168556
# improvements: 2151
# 8.6101000309
# -------
# errors: 353.521347
# change in best rf: 20.000000
# norm of feature weights: 120.731926
# improvements: 1879
# 8.59892082214
# --------candiate rf models 461 to 471
# -------
# errors: 349.759364
# ...
# norm of feature weights: 97.171661
# improvements: 4209
# 8.66987895966
# -------
# errors: 354.500921
# change in best rf: 57.000000
# norm of feature weights: 106.176788
# improvements: 3545
# 8.65311217308
# -------
# errors: 355.006217
# change in best rf: 6.000000
# norm of feature weights: 114.082016
# improvements: 3125
# 8.64078712463
# --------candiate rf models 3049 to 3059
# -------
# errors: 349.965827
# change in best rf: 103328.000000
# norm of feature weights: 4.616822
# improvements: 227010
# 0.427035093307
# -------
# errors: 350.629206
# change in best rf: -187.000000
# norm of feature weights: 36.950634
# improvements: 31934
# 9.22302699089
# -------
# errors: 351.954416
# change in best rf: -85.000000
# norm of feature weights: 58.002228
# improvements: 14741
# 8.94973301888
# -------
# errors: 353.153940
# change in best rf: -94.000000
# norm of feature weights: 73.962822
# improvements: 7931
# 8.80645608902
# -------
# errors: 354.154376
# change in best rf: 52.000000
# norm of feature weights: 86.671013
# improvements: 5293
# 8.72440814972
# -------
# errors: 354.973813
# change in best rf: -4.000000
# norm of feature weights: 97.210419
# improvements: 4176
# 8.67850208282
# -------
# errors: 355.648129
# change in best rf: -14.000000
# norm of feature weights: 106.238594
# improvements: 3571
# 8.66038894653
# -------
# errors: 356.210341
# change in best rf: -29.000000
# norm of feature weights: 114.169960
# improvements: 3122
# 8.64918684959
# --------candiate rf models 3059 to 3069
# -------
# errors: 349.839763
# change in best rf: 38582.000000
# norm of feature weights: 4.595633
# improvements: 227010
# 0.425736904144
# -------
# errors: 350.101431
# change in best rf: 11.000000
# norm of feature weights: 36.999168
# improvements: 32568
# 9.21888399124
# -------
# errors: 351.235715
# change in best rf: 86.000000
# norm of feature weights: 58.091240
# improvements: 14374
# 8.9445309639
# -------
# errors: 352.296188
# change in best rf: -2.000000
# norm of feature weights: 74.059418
# improvements: 7858
# 8.79648804665
# -------
# errors: 353.191043
# change in best rf: 24.000000
# norm of feature weights: 86.759789
# improvements: 5288
# 8.70833587646
# -------
# errors: 353.927924
# change in best rf: 69.000000
# norm of feature weights: 97.282341
# improvements: 4142
# 8.66648101807
# -------
# errors: 354.535508
# change in best rf: 23.000000
# norm of feature weights: 106.287544
# improvements: 3517
# 8.64965009689
# -------
# errors: 355.042665
# change in best rf: -5.000000
# norm of feature weights: 114.191147
# improvements: 3121
# 8.63511109352
# --------candiate rf models 3069 to 3079
# -------
# errors: 349.978334
# change in best rf: 103321.000000
# norm of feature weights: 4.596431
# improvements: 227010
# 0.429361820221
# -------
# errors: 350.644878
# change in best rf: -60.000000
# norm of feature weights: 36.999443
# improvements: 31806
# 9.22445893288
# -------
# errors: 351.978400
# change in best rf: -74.000000
# norm of feature weights: 58.086246
# improvements: 14526
# 8.95776700974
# -------
# errors: 353.184943
# change in best rf: 36.000000
# norm of feature weights: 74.070793
# improvements: 7972
# 8.81321501732
# -------
# errors: 354.190970
# change in best rf: -25.000000
# norm of feature weights: 86.796516
# improvements: 5306
# 8.72302389145
# -------
# errors: 355.014887
# change in best rf: -35.000000
# norm of feature weights: 97.348976
# improvements: 4148
# 8.67726898193
# -------
# errors: 355.692791
# change in best rf: 19.000000
# norm of feature weights: 106.386955
# improvements: 3509
# 8.65862703323
# -------
# errors: 356.257846
# change in best rf: -30.000000
# norm of feature weights: 114.325745
# improvements: 3095
# 8.64748692513
# --------candiate rf models 3079 to 3089
# -------
# errors: 349.853538
# change in best rf: 38628.000000
# norm of feature weights: 4.571085
# improvements: 227010
# 0.425535917282
# -------
# errors: 350.117124
# change in best rf: 125.000000
# norm of feature weights: 37.053902
# improvements: 32454
# 9.21990609169
# -------
# errors: 351.258269
# change in best rf: 58.000000
# norm of feature weights: 58.181343
# improvements: 14234
# 8.94031596184
# -------
# errors: 352.324916
# change in best rf: 48.000000
# norm of feature weights: 74.167473
# improvements: 7773
# 8.79260015488
# -------
# errors: 353.224622
# change in best rf: 17.000000
# norm of feature weights: 86.876213
# improvements: 5274
# 8.70935797691
# -------
# errors: 353.965110
# change in best rf: 19.000000
# norm of feature weights: 97.401489
# improvements: 4098
# 8.66663384438
# -------
# errors: 354.575589
# change in best rf: -3.000000
# norm of feature weights: 106.406143
# improvements: 3494
# 8.65020298958
# -------
# errors: 355.084602
# change in best rf: -14.000000
# norm of feature weights: 114.307098
# improvements: 3084
# 8.63462901115
# --------candiate rf models 3089 to 3099
# -------
# errors: 349.992151
# change in best rf: 103212.000000
# norm of feature weights: 4.572453
# improvements: 227010
# 0.42778801918
# -------
# errors: 350.663936
# change in best rf: -42.000000
# norm of feature weights: 37.052757
# improvements: 31625
# 9.21745896339
# -------
# errors: 352.006272
# change in best rf: 14.000000
# norm of feature weights: 58.177631
# improvements: 14473
# 8.94907593727
# -------
# errors: 353.220406
# change in best rf: -67.000000
# norm of feature weights: 74.186882
# improvements: 7983
# 8.80382204056
# -------
# errors: 354.232371
# change in best rf: 34.000000
# norm of feature weights: 86.929695
# improvements: 5234
# 8.71893191338
# -------
# errors: 355.060942
# change in best rf: -15.000000
# norm of feature weights: 97.494148
# improvements: 4125
# 8.67797708511
# -------
# errors: 355.742680
# change in best rf: -73.000000
# norm of feature weights: 106.540649
# improvements: 3417
# 8.65880203247
# -------
# errors: 356.310778
# change in best rf: -19.000000
# norm of feature weights: 114.485435
# improvements: 3024
# 8.64012122154
# --------candiate rf models 3099 to 3109
# -------
# errors: 349.868455
# change in best rf: 38427.000000
# norm of feature weights: 4.543617
# improvements: 227010
# 0.425992965698
# -------
# errors: 350.135776
# change in best rf: 141.000000
# norm of feature weights: 37.113007
# improvements: 32298
# 9.21994876862
# -------
# errors: 351.284315
# change in best rf: 88.000000
# norm of feature weights: 58.278896
# improvements: 14185
# 8.94237089157
# -------
# errors: 352.357429
# change in best rf: 71.000000
# norm of feature weights: 74.283737
# improvements: 7732
# 8.78969097137
# -------
# errors: 353.262329
# change in best rf: 33.000000
# norm of feature weights: 87.001053
# improvements: 5270
# 8.70446300507
# -------
# errors: 354.006426
# change in best rf: 46.000000
# norm of feature weights: 97.528824
# improvements: 4047
# 8.66664481163
# -------
# errors: 354.619554
# change in best rf: 39.000000
# norm of feature weights: 106.532448
# improvements: 3456
# 8.64833402634
# -------
# errors: 355.130668
# change in best rf: 17.000000
# norm of feature weights: 114.430237
# improvements: 3073
# 8.63419699669
# --------candiate rf models 3109 to 3119
# -------
# errors: 350.007034
# change in best rf: 103077.000000
# norm of feature weights: 4.545303
# improvements: 227010
# 0.427372932434
# -------
# errors: 350.685965
# change in best rf: -31.000000
# norm of feature weights: 37.109928
# improvements: 31516
# 9.21775197983
# -------
# errors: 352.037844
# change in best rf: -10.000000
# norm of feature weights: 58.275818
# improvements: 14433
# 8.94435596466
# -------
# errors: 353.259919
# change in best rf: -25.000000
# norm of feature weights: 74.310257
# improvements: 7965
# 8.79675483704
# -------
# errors: 354.278185
# change in best rf: -99.000000
# norm of feature weights: 87.069710
# improvements: 5263
# 8.71604394913
# -------
# errors: 355.111638
# change in best rf: 18.000000
# norm of feature weights: 97.645332
# improvements: 4090
# 8.67535281181
# -------
# errors: 355.797164
# change in best rf: 13.000000
# norm of feature weights: 106.699150
# improvements: 3408
# 8.65692806244
# -------
# errors: 356.368237
# change in best rf: -32.000000
# norm of feature weights: 114.648430
# improvements: 3054
# 8.64798307419
# --------candiate rf models 3119 to 3129
# -------
# errors: 349.884321
# change in best rf: 38213.000000
# norm of feature weights: 4.513653
# improvements: 227010
# 0.426719903946
# -------
# errors: 350.157013
# change in best rf: 140.000000
# norm of feature weights: 37.175743
# improvements: 32203
# 9.22041583061
# -------
# errors: 351.313820
# change in best rf: 57.000000
# norm of feature weights: 58.382660
# improvements: 14089
# 8.93866896629
# -------
# errors: 352.393777
# change in best rf: 131.000000
# norm of feature weights: 74.407257
# improvements: 7640
# 8.78608202934
# -------
# errors: 353.303629
# change in best rf: 46.000000
# norm of feature weights: 87.133423
# improvements: 5220
# 8.70158290863
# -------
# errors: 354.051549
# change in best rf: 37.000000
# norm of feature weights: 97.663963
# improvements: 4039
# 8.66306018829
# -------
# errors: 354.667481
# change in best rf: -6.000000
# norm of feature weights: 106.666481
# improvements: 3470
# 8.6449239254
# -------
# errors: 355.180646
# change in best rf: 16.000000
# norm of feature weights: 114.560776
# improvements: 3049
# 8.6310069561
# --------candiate rf models 3129 to 3139
# -------
# errors: 350.022757
# change in best rf: 103059.000000
# norm of feature weights: 4.515440
# improvements: 227010
# 0.427804231644
# -------
# errors: 350.710712
# change in best rf: 35.000000
# norm of feature weights: 37.170441
# improvements: 31325
# 9.21461105347
# -------
# errors: 352.072738
# change in best rf: 1.000000
# norm of feature weights: 58.379791
# improvements: 14307
# 8.94583702087
# -------
# errors: 353.302905
# change in best rf: -76.000000
# norm of feature weights: 74.439957
# improvements: 7976
# 8.79864215851
# -------
# errors: 354.327775
# change in best rf: -27.000000
# norm of feature weights: 87.215889
# improvements: 5300
# 8.71447610855
# -------
# errors: 355.166169
# change in best rf: 32.000000
# norm of feature weights: 97.801865
# improvements: 4120
# 8.6759250164
# -------
# errors: 355.855582
# change in best rf: 5.000000
# norm of feature weights: 106.861977
# improvements: 3487
# 8.65830111504
# -------
# errors: 356.429824
# change in best rf: 23.000000
# norm of feature weights: 114.814537
# improvements: 3051
# 8.64514398575
# --------candiate rf models 3139 to 3149
# -------
# errors: 349.900904
# change in best rf: 38107.000000
# norm of feature weights: 4.481653
# improvements: 227010
# 0.425816059113
# -------
# errors: 350.180724
# change in best rf: 136.000000
# norm of feature weights: 37.241211
# improvements: 32021
# 9.21626520157
# -------
# errors: 351.346253
# change in best rf: 103.000000
# norm of feature weights: 58.491512
# improvements: 14043
# 8.93861413002
# -------
# errors: 352.433278
# change in best rf: 26.000000
# norm of feature weights: 74.536949
# improvements: 7540
# 8.78112506866
# -------
# errors: 353.348388
# change in best rf: 11.000000
# norm of feature weights: 87.272713
# improvements: 5161
# 8.69906210899
# -------
# errors: 354.100338
# change in best rf: -35.000000
# norm of feature weights: 97.806366
# improvements: 4023
# 8.66176605225
# -------
# errors: 354.719183
# change in best rf: 65.000000
# norm of feature weights: 106.808022
# improvements: 3434
# 8.64730811119
# -------
# errors: 355.234698
# change in best rf: 5.000000
# norm of feature weights: 114.699165
# improvements: 3000
# 8.62814712524
# --------candiate rf models 3149 to 3159
# -------
# errors: 350.039095
# change in best rf: 102750.000000
# norm of feature weights: 4.483352
# improvements: 227010
# 0.426694869995
# -------
# errors: 350.737877
# change in best rf: -133.000000
# norm of feature weights: 37.233555
# improvements: 31114
# 9.21213793755
# -------
# errors: 352.110406
# change in best rf: -127.000000
# norm of feature weights: 58.488567
# improvements: 14153
# 8.94054985046
# -------
# errors: 353.349048
# change in best rf: -76.000000
# norm of feature weights: 74.574989
# improvements: 7886
# 8.79141187668
# -------
# errors: 354.380538
# change in best rf: -87.000000
# norm of feature weights: 87.367188
# improvements: 5234
# 8.71016478539
# -------
# errors: 355.224093
# change in best rf: -30.000000
# norm of feature weights: 97.963097
# improvements: 4076
# 8.67377996445
# -------
# errors: 355.917455
# change in best rf: -25.000000
# norm of feature weights: 107.028679
# improvements: 3440
# 8.65360617638
# -------
# errors: 356.494924
# change in best rf: -2.000000
# norm of feature weights: 114.983719
# improvements: 3023
# 8.63786196709
# --------candiate rf models 3159 to 3169
# -------
# errors: 349.918005
# change in best rf: 37893.000000
# norm of feature weights: 4.448058
# improvements: 227010
# 0.425531864166
# -------
# errors: 350.206495
# change in best rf: 201.000000
# norm of feature weights: 37.308605
# improvements: 31904
# 9.21740889549
# -------
# errors: 351.381230
# change in best rf: 92.000000
# norm of feature weights: 58.604401
# improvements: 14015
# 8.93885111809
# -------
# errors: 352.475147
# change in best rf: 64.000000
# norm of feature weights: 74.671638
# improvements: 7505
# 8.78002905846
# -------
# errors: 353.395669
# change in best rf: 12.000000
# norm of feature weights: 87.417938
# improvements: 5036
# 8.69894886017
# -------
# errors: 354.151824
# change in best rf: 54.000000
# norm of feature weights: 97.955345
# improvements: 3940
# 8.66030097008
# -------
# errors: 354.773715
# change in best rf: 6.000000
# norm of feature weights: 106.956810
# improvements: 3380
# 8.64143013954
# -------
# errors: 355.291445
# change in best rf: 47.000000
# norm of feature weights: 114.845253
# improvements: 2972
# 8.62906599045
# --------candiate rf models 3169 to 3179
# -------
# errors: 350.055807
# change in best rf: 102445.000000
# norm of feature weights: 4.449521
# improvements: 227010
# 0.425876140594
# -------
# errors: 350.767042
# change in best rf: -139.000000
# norm of feature weights: 37.298660
# improvements: 30952
# 9.21023106575
# -------
# errors: 352.150540
# change in best rf: -120.000000
# norm of feature weights: 58.601219
# improvements: 14035
# 8.94024300575
# -------
# errors: 353.397741
# change in best rf: -134.000000
# norm of feature weights: 74.714386
# improvements: 7795
# 8.78905487061
# -------
# errors: 354.435895
# change in best rf: -78.000000
# norm of feature weights: 87.522751
# improvements: 5224
# 8.70970988274
# -------
# errors: 355.284577
# change in best rf: -28.000000
# norm of feature weights: 98.128242
# improvements: 4045
# 8.67496395111
# -------
# errors: 355.981979
# change in best rf: -55.000000
# norm of feature weights: 107.198891
# improvements: 3410
# 8.65384888649
# -------
# errors: 356.562592
# change in best rf: 0.000000
# norm of feature weights: 115.155388
# improvements: 2957
# 8.63621020317
# --------candiate rf models 3179 to 3189
# -------
# errors: 349.935444
# change in best rf: 37553.000000
# norm of feature weights: 4.413314
# improvements: 227010
# 0.425244092941
# -------
# errors: 350.234050
# change in best rf: 94.000000
# norm of feature weights: 37.377186
# improvements: 31752
# 9.21270513535
# -------
# errors: 351.418163
# change in best rf: 121.000000
# norm of feature weights: 58.720119
# improvements: 13874
# 8.9357149601
# -------
# errors: 352.519289
# change in best rf: 26.000000
# norm of feature weights: 74.810371
# improvements: 7383
# 8.77422404289
# -------
# errors: 353.445344
# change in best rf: -1.000000
# norm of feature weights: 87.568108
# improvements: 4929
# 8.69249987602
# -------
# errors: 354.205439
# change in best rf: 39.000000
# norm of feature weights: 98.110367
# improvements: 3907
# 8.65756702423
# -------
# errors: 354.830430
# change in best rf: 20.000000
# norm of feature weights: 107.112434
# improvements: 3290
# 8.64220905304
# -------
# errors: 355.350634
# change in best rf: 36.000000
# norm of feature weights: 114.998734
# improvements: 2919
# 8.62199497223
# --------candiate rf models 3189 to 3200
# -------
# errors: 350.060967
# change in best rf: 113370.000000
# norm of feature weights: 4.624849
# improvements: 249711
# 0.464207172394
# -------
# errors: 350.756810
# change in best rf: -50.000000
# norm of feature weights: 39.219620
# improvements: 33674
# 10.0526621342
# -------
# errors: 352.135784
# change in best rf: -81.000000
# norm of feature weights: 61.627953
# improvements: 15210
# 9.74796199799
# -------
# errors: 353.380515
# change in best rf: -7.000000
# norm of feature weights: 78.563187
# improvements: 8425
# 9.58718514442
# -------
# errors: 354.417034
# change in best rf: -39.000000
# norm of feature weights: 92.016624
# improvements: 5664
# 9.50396609306
# -------
# errors: 355.264338
# change in best rf: -7.000000
# norm of feature weights: 103.149590
# improvements: 4400
# 9.45423698425
# -------
# errors: 355.960447
# change in best rf: -33.000000
# norm of feature weights: 112.666130
# improvements: 3682
# 9.43456697464
# -------
# errors: 356.539864
# change in best rf: -30.000000
# norm of feature weights: 121.009590
# improvements: 3203
# 9.41763305664
# 22460.8381512

# %% [markdown]
# #### loss histories, all voxels

# %%
_=plt.plot(beh[:,1:]-beh[0,1:])

# %% [markdown]
# #### view loss history for a few voxels

# %%
_=plt.plot(beh[:,slice(0,-1,200)]-beh[0,slice(0,-1,200)])

# %%
##loss in "final_validation_loss" = last point of "best_error_history"
print np.min(beh[:,-2])
print fvl[-2]
# Out:
# 274.98626709
# 274.98626709

# %% [markdown]
# #### diff between first and last point of loss history, all voxels

# %%
_=plt.hist(beh[0,1:]-np.min(beh[:,1:],axis=0),100)
plt.yscale('log')

# %% [markdown]
# ### Step 6: model analysis and validation

# %% [markdown]
# #### histogram of rf models selected for each voxel

# %%
_=plt.hist(frf,ms.receptive_fields.G)
plt.xlabel('smaller-->bigger')

# %% [markdown]
# #### sum of all selected rfs.

# %%
plt.imshow(np.sum(ms.receptive_fields.make_rf_stack(64, min_pix_per_radius=1)[frf,:,:], axis=0), cmap='hot')

# %% [markdown]
# #### prediction accuracy for all voxels

# %%
##generate predictions
# pred = prediction_menu(val_mst, ffw[np.newaxis,:,:], rf_indices = frf) ##<<too big, choked. 


##generate predictions one voxel at a time
pred = np.zeros((Tval,nvox))
for v in range(nvox):  ##<<some kind of bug in training function, last voxel getting skipped.
    pred[:,v] = np.squeeze(bigmult(validation_mst[np.newaxis,frf[v],:,:],
                                   ffw[np.newaxis,:,v, np.newaxis]))

# %%
validation_mst.shape

# %%
##get correlation = prediction accuracy
val_cc = []  
for v in range(nvox): 
    cc = pearsonr(val_voxel_data[:,v],pred[:,v])
    if not np.isnan(cc[0]):
        val_cc.append(cc[0])

# %%
##histogram of prediction accuracy, all voxels
_=plt.hist(val_cc,100)
plt.yscale('log')
plt.ylim([10**0, 10**3])
plt.xlim([-.4, 0.9])
# Out:
# (-0.4, 0.9)

# %% [markdown]
# #### compare to deepnet model

# %%
deepnet_valcc  = h5py.File('/media/tnaselar/Data/deepnet_vim-1/feature_weighted_models/conv5_seperable.hdf5','r')['conv5_validation_cc']

# %%
plt.figure(figsize=(8,8))
plt.plot(val_cc, deepnet_valcc, '.')
plt.xlim([-0.4, 1])
plt.ylim([-0.4, 1])
plt.axes().set_aspect(1)
plt.plot(np.linspace(-1, 1, num=100),np.linspace(-1, 1, num=100))

plt.xlabel('gabor model prediction accuracy (Pearson correlation)')
plt.ylabel('deepnet model prediction accuracy (Pearson correlation)')

# %% [markdown]
# huh. the deepnet model is so so much better.

# %% [markdown]
# #### area-wise rf size vs. eccentricity

# %%
##get position information. need to re-open file
voxel_file = '/media/tnaselar/Data/crcns_datasets/vim-1/EstimatedResponses.mat'
crcns_voxel_data = h5py.File(voxel_file,'r')

vox_position = crcns_voxel_data['voxIdxS1'][0,no_nan]  ##index into a 64 x 64 x 18 volume (matlab-style raveling)

##get the indices for visual areas
roi_indicator = crcns_voxel_data['roiS1'][0, no_nan]
roi_names = ['other', 'v1', 'v2', 'v3', 'v3A', 'v3B', 'v4', 'LO']

crcns_voxel_data.close()

# %%
## construct data table of rfs--indices will now be voxels
frf_sizes = ms.receptive_fields.rf_table.loc[frf,'deg_per_radius'].values
frf_eccentricities = ms.receptive_fields.rf_table.loc[frf, ['x_deg','y_deg']].apply(lambda row: np.sqrt(row['x_deg']**2+row['y_deg']**2),axis=1).values
named_voxels = [roi_names[int(v)] for v in roi_indicator]

# %%
model_table = pd.DataFrame(data=list(frf_sizes), columns=['roi_size'])
model_table['eccentricity'] = frf_eccentricities
model_table['area'] = named_voxels
model_table['valcc'] = val_cc

model_table
# Out:
#        roi_size  eccentricity   area     valcc
# 0      0.500000      6.862318  other  0.041179
# 1      0.500000      9.206766  other  0.138408
# 2      0.500000     11.554999  other  0.042990
# 3      0.500000     11.164844  other  0.078456
# 4      0.500000      7.912261  other  0.012849
# 5      0.500000      2.683694  other  0.064409
# 6      0.500000      8.962835  other  0.023412
# 7      0.500000      7.480353  other  0.042386
# 8      0.500000      5.418753  other -0.093587
# 9      0.500000     10.123886  other  0.108658
# 10     0.500000      9.676198  other  0.012663
# 11     0.500000      7.330731  other -0.178121
# 12     0.500000     10.447070  other -0.006757
# 13     0.500000      1.664357  other -0.004180
# 14     0.500000      0.744323  other  0.188733
# 15     2.642857      3.068922  other  0.147937
# 16     2.642857      5.418753  other -0.175952
# 17     0.500000     14.142136  other -0.014778
# 18     0.500000      9.206766  other -0.000196
# 19     1.571429     10.657082  other  0.132860
# 20     0.500000      7.330731  other  0.015205
# 21     1.571429     12.740756  other  0.113792
# 22     0.500000      8.051083  other  0.136234
# 23     0.500000      8.962835  other -0.130883
# 24     0.500000     10.123886  other -0.035813
# 25     0.500000      5.210260  other -0.005279
# 26     0.500000     12.740756  other -0.060020
# 27     1.571429      6.862318  other -0.035391
# 28     1.571429      5.813348  other -0.009703
# 29     0.500000      4.765992  other  0.086276
# ...         ...           ...    ...       ...
# 22671  0.500000      6.000923  other  0.122647
# 22672  0.500000      7.480353  other -0.062103
# 22673  1.571429     10.123886  other  0.031971
# 22674  0.500000      4.993070  other  0.225254
# 22675  0.500000     12.116699  other  0.106786
# 22676  0.500000      6.862318  other  0.004564
# 22677  0.500000      6.862318  other -0.015051
# 22678  0.500000      4.008302  other  0.033156
# 22679  0.500000      8.712077     v4 -0.015140
# 22680  0.500000     12.116699  other  0.085857
# 22681  0.500000      7.021928  other  0.082684
# 22682  1.571429      6.000923  other  0.157465
# 22683  1.571429     11.065156  other -0.077114
# 22684  1.571429      1.664357  other -0.050352
# 22685  0.500000      9.085619  other  0.030717
# 22686  2.642857     10.340465  other -0.061750
# 22687  0.500000      7.480353  other  0.032368
# 22688  0.500000      7.330731  other -0.025320
# 22689  0.500000      9.790040  other -0.060756
# 22690  0.500000      7.770960  other  0.003797
# 22691  0.500000      9.676198  other  0.102636
# 22692  1.571429      6.000923  other -0.021097
# 22693  0.500000     12.740756  other  0.001213
# 22694  0.500000      8.962835  other -0.109605
# 22695  0.500000      7.021928  other  0.169671
# 22696  0.500000      7.330731  other -0.003077
# 22697  0.500000      8.321783  other -0.082594
# 22698  0.500000     10.123886  other -0.036414
# 22699  0.500000      2.683694  other  0.045661
# 22700  0.500000      4.527540  other -0.146728
#
# [22701 rows x 4 columns]

# %%
val_thresh = 0.25
size_means = {}
size_stds = {}
area_eccs = {}
for roi in roi_names:
    area_stats = model_table.loc[(model_table['area']==roi) & (model_table['valcc'] > val_thresh),['roi_size', 'eccentricity']]
    ecc_grp = area_stats.groupby(by='eccentricity')
    size_means[roi] = []
    size_stds[roi] = []
    area_eccs[roi] = []
    for name,grp in ecc_grp:
        area_eccs[roi].append(name)
        size_means[roi].append(grp.roi_size.mean())
        size_stds[roi].append(grp.roi_size.std())

# %%
roi_colors = ['black', 'r', 'salmon', 'coral', 'darkslategray', 'teal','orangered', 'indigo' ]
ecc = np.sort(np.unique(model_table['eccentricity']))
line_list = []
fig = plt.figure(figsize=(10,10))
for r,roi in enumerate(roi_names):
    plt.plot(area_eccs[roi],size_means[roi], 'o', color=roi_colors[r])
    p = np.polyfit(area_eccs[roi],size_means[roi],1)
    l, = plt.plot(area_eccs[roi], np.polyval(p,area_eccs[roi]), color=roi_colors[r], label=roi, linewidth=4)
    line_list.append(l)
    
plt.legend(loc='upper left', ncol = 4)    
# plt.axis('equal')
plt.xlim([0,14])
plt.ylim([0,8])
plt.xlabel('eccentricity (deg)')
plt.ylabel('rf size (deg.)')

# %% [markdown]
# #### area-wise prediction accuracy

# %%
areawise_accuracy = []
deepnet_areawise_accuracy = []
for ii,roi in enumerate(roi_names):
    voxels_in_roi = roi_indicator == ii
    areawise_accuracy.append(np.array(val_cc)[voxels_in_roi])
    deepnet_areawise_accuracy.append(np.array(deepnet_valcc)[voxels_in_roi])
n_rois = len(roi_names)

# %%
fig = plt.figure(figsize = (4,12))
for ii,roi in enumerate(roi_names):
    plt.subplot(n_rois,1,ii+1)
    plt.hist(areawise_accuracy[ii],100)
    plt.yscale('log')
    plt.xlim([-0.4, 0.85])
    plt.ylim([0, 10**3])
    plt.title(roi)
plt.tight_layout()

# %% [markdown]
# #### area-wise comparison to deepnet

# %%
fig = plt.figure(figsize = (5,40))
for ii,roi in enumerate(roi_names):
    plt.subplot(n_rois,1,ii+1)
    plt.plot(areawise_accuracy[ii],deepnet_areawise_accuracy[ii], '.')
    plt.axis('equal')
    plt.plot(np.linspace(-1, 1, num=100),np.linspace(-1, 1, num=100),hold=True)
    plt.xlim([-0.4, 1])
    plt.ylim([-0.4, 1])

    plt.title(roi)
plt.tight_layout()
