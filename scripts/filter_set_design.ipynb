# %%
# %pylab inline
import numpy as np
import pandas as pd
import scipy.ndimage

from mpl_toolkits.axes_grid1 import ImageGrid
from PIL import Image
from hrf_fitting.src.features import make_gaussian,make_a_ripple,construct_placement_grid,make_kernel_grid
from scipy.signal import convolve2d,convolve
from skimage.filter import gabor_kernel,gabor_filter
from glob import glob
from os import path
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X,Y=construct_placement_grid((-25,25,-25,25),5)
kernels = make_kernel_grid(5,25,50,(X,Y))
# Out:
# constructing 100 filters

# %%
plt.figure
plt.subplot(1,3,1)
plt.imshow(np.real(kernels[9,:,:]), cmap=cm.gray)
plt.subplot(1,3,2)
plt.imshow(np.real(kernels[44,:,:]), cmap=cm.gray)
plt.subplot(1,3,3)
plt.scatter(X,Y,)
plt.axis('tight')
plt.xlim((-26,26))
plt.ylim((-26, 26))
plt.axis('equal')
# Out:
# (-30.0, 30.0, -30.0, 30.0)

# %%
64**2*10/60./60.
# Out:
# 11.377777777777776
